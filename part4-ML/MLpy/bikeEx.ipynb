# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
train=pd.read_csv("bike-sharing-demand/train.csv", parse_dates=['datetime'])
train.shape
test=pd.read_csv("bike-sharing-demand/test.csv", parse_dates=['datetime'])
test.shape

train['year']=train['datetime'].dt.year
train['month']=train['datetime'].dt.month
train['day']=train['datetime'].dt.day
train['hour']=train['datetime'].dt.hour
train['minute']=train['datetime'].dt.minute
train['second']=train['datetime'].dt.second
train['dayofweek']=train['datetime'].dt.dayofweek
train.shape

#풍속이 0인 값을 일괄적으로 평균으로 대체
#train.loc[train['windspeed']==0,'windspeed']=train['windspeed'].mean()
#test.loc[train['windspeed']==0,'windspeed']=train['windspeed'].mean()

#train.loc[train['windspeed']==0]
trainWind0=train.loc[train['windspeed']==0]
trainWindNot0=train.loc[train['windspeed']!=0]
#풍속0, 풍속이 0이 아닌것
print(trainWind0.shape)
print(trainWindNot0.shape)
# Out:
# (1313, 19)
# (9573, 19)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
dataWind0=train.loc[train['windspeed']==0]
dataWindNot0=train.loc[train['windspeed']!=0]
wCol=['season', 'weather', 'humidity', 'month','temp', 'year', 'atemp']
dataWindNot0['windspeed']=dataWindNot0['windspeed'].astype('str')
# 이 라벨을 str로 바꿔줘야 하는구나
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
dataWind0.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  second  dayofweek
# 0       0       0          5
# ...

# %%
dataWindNot0.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 5  2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 10 2011-01-01 10:00:00       1        0           0        1  15.58  19.695
# 11 2011-01-01 11:00:00       1        0           0        1  14.76  16.665
# 12 2011-01-01 12:00:00       1        0           0        1  17.22  21.210
# 13 2011-01-01 13:00:00       1        0           0        2  18.86  22.725
#
#     humidity windspeed  casual  registered  count  year  month  day  hour  \
# 5         75    6.0032       0           1      1  2011      1    1     5
# 10        76   16.9979      12          24     36  2011      1    1    10
# 11        81   19.0012      26          30     56  2011      1    1    11
# 12        77   19.0012      29          55     84  2011      1    1    12
# 13        72   19.9995      47          47     94  2011      1    1    13
#
#     minute  second  dayofweek
# 5        0       0          5
# ...

# %%
model_wind = RandomForestClassifier()
model_wind.fit(dataWindNot0[wCol],dataWindNot0['windspeed'])
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
dataWindNot0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9573 entries, 5 to 10885
# Data columns (total 19 columns):
# datetime      9573 non-null datetime64[ns]
# season        9573 non-null int64
# holiday       9573 non-null int64
# workingday    9573 non-null int64
# weather       9573 non-null int64
# temp          9573 non-null float64
# atemp         9573 non-null float64
# humidity      9573 non-null int64
# windspeed     9573 non-null object
# casual        9573 non-null int64
# registered    9573 non-null int64
# count         9573 non-null int64
# year          9573 non-null int64
# month         9573 non-null int64
# day           9573 non-null int64
# hour          9573 non-null int64
# minute        9573 non-null int64
# second        9573 non-null int64
# dayofweek     9573 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(15), object(1)
# memory usage: 1.5+ MB

# %%
wind0Values=model_wind.predict(X=dataWind0[wCol])

# %%
# 둘이 분리하면 인덱스는 쥐파먹은듯이 분리됨!
dataWind0.head(10)
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 6  2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7  2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8  2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9  2011-01-01 09:00:00       1        0           0        1  13.12  17.425
# 64 2011-01-03 19:00:00       1        0           1        1   8.20  12.880
#
#     humidity  windspeed  casual  registered  count  year  month  day  hour  \
# ...

# %%
dataWindNot0.head(10)
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 5  2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 10 2011-01-01 10:00:00       1        0           0        1  15.58  19.695
# 11 2011-01-01 11:00:00       1        0           0        1  14.76  16.665
# 12 2011-01-01 12:00:00       1        0           0        1  17.22  21.210
# 13 2011-01-01 13:00:00       1        0           0        2  18.86  22.725
# 14 2011-01-01 14:00:00       1        0           0        2  18.86  22.725
# 15 2011-01-01 15:00:00       1        0           0        2  18.04  21.970
# 16 2011-01-01 16:00:00       1        0           0        2  17.22  21.210
# 17 2011-01-01 17:00:00       1        0           0        2  18.04  21.970
# 18 2011-01-01 18:00:00       1        0           0        3  17.22  21.210
#
#     humidity windspeed  casual  registered  count  year  month  day  hour  \
# ...

# %%
predictWind0 = dataWind0

# %%
predictWind0
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# 6     2011-01-01 06:00:00       1        0           0        1   9.02
# 7     2011-01-01 07:00:00       1        0           0        1   8.20
# 8     2011-01-01 08:00:00       1        0           0        1   9.84
# 9     2011-01-01 09:00:00       1        0           0        1  13.12
# 64    2011-01-03 19:00:00       1        0           1        1   8.20
# 89    2011-01-04 21:00:00       1        0           1        1   9.02
# 92    2011-01-05 00:00:00       1        0           1        1   8.20
# ...

# %%
predictWindNot0 = dataWindNot0

# %%
predictWindNot0
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 5     2011-01-01 05:00:00       1        0           0        2   9.84
# 10    2011-01-01 10:00:00       1        0           0        1  15.58
# 11    2011-01-01 11:00:00       1        0           0        1  14.76
# 12    2011-01-01 12:00:00       1        0           0        1  17.22
# 13    2011-01-01 13:00:00       1        0           0        2  18.86
# 14    2011-01-01 14:00:00       1        0           0        2  18.86
# 15    2011-01-01 15:00:00       1        0           0        2  18.04
# 16    2011-01-01 16:00:00       1        0           0        2  17.22
# 17    2011-01-01 17:00:00       1        0           0        2  18.04
# 18    2011-01-01 18:00:00       1        0           0        3  17.22
# 19    2011-01-01 19:00:00       1        0           0        3  17.22
# 20    2011-01-01 20:00:00       1        0           0        2  16.40
# ...

# %%
predictWind0['windspeed'] = wind0Values
predictWind0.head(10)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 6  2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# ...

# %%
predictWind0.info() # 이거 하면 여전히 windspeed는 1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1313 entries, 0 to 10862
# Data columns (total 19 columns):
# datetime      1313 non-null datetime64[ns]
# season        1313 non-null int64
# holiday       1313 non-null int64
# workingday    1313 non-null int64
# weather       1313 non-null int64
# temp          1313 non-null float64
# atemp         1313 non-null float64
# humidity      1313 non-null int64
# windspeed     1313 non-null object
# casual        1313 non-null int64
# registered    1313 non-null int64
# count         1313 non-null int64
# year          1313 non-null int64
# month         1313 non-null int64
# day           1313 non-null int64
# hour          1313 non-null int64
# minute        1313 non-null int64
# second        1313 non-null int64
# dayofweek     1313 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(15), object(1)
# memory usage: 205.2+ KB

# %%
data = predictWindNot0.append(predictWind0)
data
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 5     2011-01-01 05:00:00       1        0           0        2   9.84
# 10    2011-01-01 10:00:00       1        0           0        1  15.58
# 11    2011-01-01 11:00:00       1        0           0        1  14.76
# 12    2011-01-01 12:00:00       1        0           0        1  17.22
# 13    2011-01-01 13:00:00       1        0           0        2  18.86
# 14    2011-01-01 14:00:00       1        0           0        2  18.86
# 15    2011-01-01 15:00:00       1        0           0        2  18.04
# 16    2011-01-01 16:00:00       1        0           0        2  17.22
# 17    2011-01-01 17:00:00       1        0           0        2  18.04
# 18    2011-01-01 18:00:00       1        0           0        3  17.22
# 19    2011-01-01 19:00:00       1        0           0        3  17.22
# 20    2011-01-01 20:00:00       1        0           0        2  16.40
# ...

# %%
# data['windspeed']=data['windspeed'].astype('float')

# %%
# data.reset_index(inplace=True)
# data

# %%
data.reset_index(inplace=True)
data['windspeed']=data['windspeed'].astype('float')
data
# 오잉? 데이터 value(datetime을 보니)가 시간순으로 안 되어 있잖아!
# Out:
#        index            datetime  season  holiday  workingday  weather   temp  \
# 0          5 2011-01-01 05:00:00       1        0           0        2   9.84
# 1         10 2011-01-01 10:00:00       1        0           0        1  15.58
# 2         11 2011-01-01 11:00:00       1        0           0        1  14.76
# 3         12 2011-01-01 12:00:00       1        0           0        1  17.22
# 4         13 2011-01-01 13:00:00       1        0           0        2  18.86
# 5         14 2011-01-01 14:00:00       1        0           0        2  18.86
# 6         15 2011-01-01 15:00:00       1        0           0        2  18.04
# 7         16 2011-01-01 16:00:00       1        0           0        2  17.22
# 8         17 2011-01-01 17:00:00       1        0           0        2  18.04
# 9         18 2011-01-01 18:00:00       1        0           0        3  17.22
# 10        19 2011-01-01 19:00:00       1        0           0        3  17.22
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 20 columns):
# index         10886 non-null int64
# datetime      10886 non-null datetime64[ns]
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# year          10886 non-null int64
# month         10886 non-null int64
# day           10886 non-null int64
# hour          10886 non-null int64
# minute        10886 non-null int64
# second        10886 non-null int64
# dayofweek     10886 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(16)
# memory usage: 1.7 MB

# %%
data = data.sort_values(by='index').set_index('index')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10886 entries, 0 to 10885
# Data columns (total 19 columns):
# datetime      10886 non-null datetime64[ns]
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# year          10886 non-null int64
# month         10886 non-null int64
# day           10886 non-null int64
# hour          10886 non-null int64
# minute        10886 non-null int64
# second        10886 non-null int64
# dayofweek     10886 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(15)
# memory usage: 1.7 MB

# %%
data.head(10)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# index
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# 5     2011-01-01 05:00:00       1        0           0        2   9.84
# 6     2011-01-01 06:00:00       1        0           0        1   9.02
# 7     2011-01-01 07:00:00       1        0           0        1   8.20
# 8     2011-01-01 08:00:00       1        0           0        1   9.84
# 9     2011-01-01 09:00:00       1        0           0        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# index
# 0      14.395        81     6.0032       3          13     16  2011      1
# ...

# %%
# 좀있다가 이제 train / test 데이터만 형식만 바꿔주고 다시 돌려보자!
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10886 entries, 0 to 10885
# Data columns (total 19 columns):
# datetime      10886 non-null datetime64[ns]
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# year          10886 non-null int64
# month         10886 non-null int64
# day           10886 non-null int64
# hour          10886 non-null int64
# minute        10886 non-null int64
# second        10886 non-null int64
# dayofweek     10886 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(15)
# memory usage: 1.7 MB

# %%
catlist = ['season','holiday','workingday','weather','month','hour','dayofweek']

# %%
data['year'] = data['year'].map({2011:0, 2012:1})

# %%
for cat in catlist:
    data[cat] = data[cat].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10886 entries, 0 to 10885
# Data columns (total 19 columns):
# datetime      10886 non-null datetime64[ns]
# season        10886 non-null category
# holiday       10886 non-null category
# workingday    10886 non-null category
# weather       10886 non-null category
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# year          10886 non-null int64
# month         10886 non-null category
# day           10886 non-null int64
# hour          10886 non-null category
# minute        10886 non-null int64
# second        10886 non-null int64
# dayofweek     10886 non-null category
# dtypes: category(7), datetime64[ns](1), float64(3), int64(8)
# memory usage: 1.2 MB

# %%
droplist = ['datetime','casual','registered','count','day','minute','second']
data.drop(droplist,axis=1).info()
data_label = data['count']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# season        10886 non-null category
# holiday       10886 non-null category
# workingday    10886 non-null category
# weather       10886 non-null category
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# year          10886 non-null int64
# month         10886 non-null category
# hour          10886 non-null category
# dayofweek     10886 non-null category
# dtypes: category(7), float64(3), int64(2)
# memory usage: 586.8 KB

# %%
data = data.drop(droplist,axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# season        10886 non-null category
# holiday       10886 non-null category
# workingday    10886 non-null category
# weather       10886 non-null category
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# year          10886 non-null int64
# month         10886 non-null category
# hour          10886 non-null category
# dayofweek     10886 non-null category
# dtypes: category(7), float64(3), int64(2)
# memory usage: 586.8 KB

# %%
train_submit = pd.get_dummies(data)
train_submit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10886 entries, 0 to 10885
# Data columns (total 60 columns):
# temp            10886 non-null float64
# atemp           10886 non-null float64
# humidity        10886 non-null int64
# windspeed       10886 non-null float64
# year            10886 non-null int64
# season_1        10886 non-null uint8
# season_2        10886 non-null uint8
# season_3        10886 non-null uint8
# season_4        10886 non-null uint8
# holiday_0       10886 non-null uint8
# holiday_1       10886 non-null uint8
# workingday_0    10886 non-null uint8
# workingday_1    10886 non-null uint8
# weather_1       10886 non-null uint8
# weather_2       10886 non-null uint8
# weather_3       10886 non-null uint8
# weather_4       10886 non-null uint8
# month_1         10886 non-null uint8
# month_2         10886 non-null uint8
# month_3         10886 non-null uint8
# month_4         10886 non-null uint8
# month_5         10886 non-null uint8
# ...

# %%
test_submit = test.copy()

# %%
test_submit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 9 columns):
# datetime      6493 non-null datetime64[ns]
# season        6493 non-null int64
# holiday       6493 non-null int64
# workingday    6493 non-null int64
# weather       6493 non-null int64
# temp          6493 non-null float64
# atemp         6493 non-null float64
# humidity      6493 non-null int64
# windspeed     6493 non-null float64
# dtypes: datetime64[ns](1), float64(3), int64(5)
# memory usage: 456.6 KB

# %%
test_submit.head(10)
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
# 5 2011-01-20 05:00:00       1        0           1        1   9.84  11.365
# 6 2011-01-20 06:00:00       1        0           1        1   9.02  10.605
# 7 2011-01-20 07:00:00       1        0           1        1   9.02  10.605
# 8 2011-01-20 08:00:00       1        0           1        1   9.02  10.605
# 9 2011-01-20 09:00:00       1        0           1        2   9.84  11.365
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# ...

# %%
test_submit['year']=test_submit['datetime'].dt.year
test_submit['month']=test_submit['datetime'].dt.month
test_submit['hour']=test_submit['datetime'].dt.hour
test_submit['dayofweek']=test_submit['datetime'].dt.dayofweek

# %%
test_submit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 13 columns):
# datetime      6493 non-null datetime64[ns]
# season        6493 non-null int64
# holiday       6493 non-null int64
# workingday    6493 non-null int64
# weather       6493 non-null int64
# temp          6493 non-null float64
# atemp         6493 non-null float64
# humidity      6493 non-null int64
# windspeed     6493 non-null float64
# year          6493 non-null int64
# month         6493 non-null int64
# hour          6493 non-null int64
# dayofweek     6493 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(9)
# memory usage: 659.5 KB

# %%
test_submit['year'] = test_submit['year'].map({2011:0,2012:1})

# %%
test_submit = test_submit.drop('datetime',axis=1)

# %%
test_submit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 12 columns):
# season        6493 non-null int64
# holiday       6493 non-null int64
# workingday    6493 non-null int64
# weather       6493 non-null int64
# temp          6493 non-null float64
# atemp         6493 non-null float64
# humidity      6493 non-null int64
# windspeed     6493 non-null float64
# year          6493 non-null int64
# month         6493 non-null int64
# hour          6493 non-null int64
# dayofweek     6493 non-null int64
# dtypes: float64(3), int64(9)
# memory usage: 608.8 KB

# %%
catlist = ['season','holiday','workingday','weather','month','hour','dayofweek']

# %%
for cat in catlist:
    test_submit[cat] = test_submit[cat].astype('category')

# %%
pd.get_dummies(test_submit).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 60 columns):
# temp            6493 non-null float64
# atemp           6493 non-null float64
# humidity        6493 non-null int64
# windspeed       6493 non-null float64
# year            6493 non-null int64
# season_1        6493 non-null uint8
# season_2        6493 non-null uint8
# season_3        6493 non-null uint8
# season_4        6493 non-null uint8
# holiday_0       6493 non-null uint8
# holiday_1       6493 non-null uint8
# workingday_0    6493 non-null uint8
# workingday_1    6493 non-null uint8
# weather_1       6493 non-null uint8
# weather_2       6493 non-null uint8
# weather_3       6493 non-null uint8
# weather_4       6493 non-null uint8
# month_1         6493 non-null uint8
# month_2         6493 non-null uint8
# month_3         6493 non-null uint8
# month_4         6493 non-null uint8
# month_5         6493 non-null uint8
# month_6         6493 non-null uint8
# ...

# %%
test_submit = pd.get_dummies(test_submit)

# %%
#classifiaction.
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC,SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

#regression
from sklearn.linear_model import LinearRegression,Ridge,Lasso,RidgeCV
from sklearn.ensemble import RandomForestRegressor,BaggingRegressor,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

#model selection
from sklearn.model_selection import train_test_split,cross_validate
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

#evaluation metrics
from sklearn.metrics import mean_squared_log_error,mean_squared_error, r2_score,mean_absolute_error # for regression
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score  # for classification

# %%
x_train,x_test,y_train,y_test=\
train_test_split(train_submit,data_label,test_size=0.25,random_state=42)

# %%
rfRegressor = RandomForestRegressor()
rfRegressor.fit(train_submit,data_label) # 학습은 진또배기로 시킴
test_pred = rfRegressor.predict(x_test)
rmsle = np.sqrt(mean_squared_log_error(test_pred,y_test))
print(rmsle)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.23062421575255182

# %%
real_pred = rfRegressor.predict(test_submit)
real_pred
# Out:
# array([ 16. ,   5.1,   4.9, ..., 130.2,  99.1,  46.5])

# %%
test_submit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 12 columns):
# season        6493 non-null category
# holiday       6493 non-null category
# workingday    6493 non-null category
# weather       6493 non-null category
# temp          6493 non-null float64
# atemp         6493 non-null float64
# humidity      6493 non-null int64
# windspeed     6493 non-null float64
# year          6493 non-null int64
# month         6493 non-null category
# hour          6493 non-null category
# dayofweek     6493 non-null category
# dtypes: category(7), float64(3), int64(2)
# memory usage: 300.2 KB

# %%
sub = pd.DataFrame()
sub['datetime'] = test['datetime']
sub['count'] = real_pred
sub.to_csv('submission_bike_6.csv',index=False)
