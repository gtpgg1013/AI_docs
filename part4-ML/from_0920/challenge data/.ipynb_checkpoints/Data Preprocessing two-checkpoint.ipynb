# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from collections import Counter

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve

sns.set(style='white', context='notebook', palette='deep')

# %%
train = pd.read_csv('train2.csv')
test = pd.read_table('test2.txt',sep=',')
# Out:
# C:\Users\KTH\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: read_table is deprecated, use read_csv instead.

# %%
train.head()
# Out:
#    index  age           job  marital  education default  balance housing loan  \
# 0      0   58    management  married   tertiary      no     2143     yes   no
# 1      1   44    technician   single  secondary      no       29     yes   no
# 2      2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3      3   47   blue-collar  married    unknown      no     1506     yes   no
# 4      4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome subscribe
# 0  unknown    5   may       261         1     -1         0  unknown        no
# 1  unknown    5   may       151         1     -1         0  unknown        no
# 2  unknown    5   may        76         1     -1         0  unknown        no
# 3  unknown    5   may        92         1     -1         0  unknown        no
# 4  unknown    5   may       198         1     -1         0  unknown        no

# %%
train.columns
# Out:
# Index(['index', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'subscribe'],
#       dtype='object')

# %%
train.isnull().sum()
# Out:
# index        0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# subscribe    0
# dtype: int64

# %%
train.shape
# Out:
# (40211, 18)

# %% [markdown]
# ## class -> label Encoding

# %%
# from sklearn.preprocessing import LabelEncoder
# enclist = []
# classlist = ['job','marital','education','default','housing','loan','contact','month','subscribe','poutcome']
# for cl in classlist:
#     enc = LabelEncoder()
#     train[cl] = enc.fit_transform(train[cl])
#     enclist.append(enc)

# %%
# sns.pairplot(train)

# %% [markdown]
# ## After scaling

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaled_train = scaler.fit_transform(train)
# scaled_train = pd.DataFrame(scaled_train, columns=train.columns)

# %%
# scaled_train.head()
# Out:
#       index       age       job   marital  education  default   balance  \
# 0 -1.732008  1.810841 -0.081866 -0.256610   1.077353 -0.14329  0.298384
# 1 -1.731922  0.359827  1.437239  1.394358  -0.271384 -0.14329 -0.429793
# 2 -1.731835 -0.780256 -0.689508 -0.256610  -0.271384 -0.14329 -0.439093
# 3 -1.731749  0.670758 -0.993329 -0.256610   2.426090 -0.14329  0.078966
# 4 -1.731663 -0.780256  2.044881  1.394358   2.426090 -0.14329 -0.439437
#
#     housing      loan   contact       day     month  duration  campaign  \
# 0  0.818385 -0.456955  1.419493 -1.320319  0.857288  0.023756 -0.580614
# 1  0.818385 -0.456955  1.419493 -1.320319  0.857288 -0.400649 -0.580614
# 2  0.818385  2.188398  1.419493 -1.320319  0.857288 -0.690016 -0.580614
# 3  0.818385 -0.456955  1.419493 -1.320319  0.857288 -0.628284 -0.580614
# 4 -1.221919 -0.456955  1.419493 -1.320319  0.857288 -0.219313 -0.580614
#
#       pdays  previous  poutcome  subscribe
# 0 -0.362434 -0.195556  0.384574  -0.283069
# 1 -0.362434 -0.195556  0.384574  -0.283069
# 2 -0.362434 -0.195556  0.384574  -0.283069
# 3 -0.362434 -0.195556  0.384574  -0.283069
# 4 -0.362434 -0.195556  0.384574  -0.283069

# %% [markdown]
# ## Remove Outlier

# %%
numerical_list = ['age','balance','duration','campaign','day','pdays','previous']

# %%
# Outlier detection 

def detect_outliers(df,n,features):
    """
    Takes a dataframe df of features and returns a list of the indices
    corresponding to the observations containing more than n outliers according
    to the Tukey method.
    """
    outlier_indices = []
    
    # iterate over features(columns)
    for col in features:
        # 1st quartile (25%)
        Q1 = np.percentile(df[col], 25)
        # 3rd quartile (75%)
        Q3 = np.percentile(df[col],75)
        # Interquartile range (IQR)
        IQR = Q3 - Q1
        
        # outlier step
        outlier_step = 1.5 * IQR
        
        # Determine a list of indices of outliers for feature col
        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step )].index
        
        # append the found outlier indices for col to the list of outlier indices 
        outlier_indices.extend(outlier_list_col)
        
    # select observations containing more than 2 outliers
    outlier_indices = Counter(outlier_indices)        
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )
    
    return multiple_outliers

# detect outliers from age, balance, duration
outliers_to_drop = detect_outliers(train, 2, numerical_list)

# %%
len(outliers_to_drop)
# Out:
# 1083

# %%
# Drop outliers
train = train.drop(outliers_to_drop, axis=0).reset_index(drop=True)

# %%
# joining train & test set
train_len = len(train)
dataset = pd.concat(objs=[train, test], axis=0).reset_index(drop=True)
# Out:
# C:\Users\KTH\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dataset.head()
# Out:
#    age  balance  campaign  contact  day default  duration  education housing  \
# 0   58     2143         1  unknown    5      no       261   tertiary     yes
# 1   44       29         1  unknown    5      no       151  secondary     yes
# 2   33        2         1  unknown    5      no        76  secondary     yes
# 3   47     1506         1  unknown    5      no        92    unknown     yes
# 4   33        1         1  unknown    5      no       198    unknown      no
#
#    index           job loan  marital month  pdays poutcome  previous subscribe
# 0      0    management   no  married   may     -1  unknown         0        no
# 1      1    technician   no   single   may     -1  unknown         0        no
# 2      2  entrepreneur  yes  married   may     -1  unknown         0        no
# 3      3   blue-collar   no  married   may     -1  unknown         0        no
# 4      4       unknown   no   single   may     -1  unknown         0        no

# %%
dataset.tail()
# Out:
#        age  balance  campaign    contact  day default  duration  education  \
# 44123   51      825         3   cellular   17      no       977   tertiary
# 44124   71     1729         2   cellular   17      no       456    primary
# 44125   72     5715         5   cellular   17      no      1127  secondary
# 44126   57      668         4  telephone   17      no       508  secondary
# 44127   37     2971         2   cellular   17      no       361  secondary
#
#       housing  index           job loan   marital month  pdays poutcome  \
# 44123      no  45206    technician   no   married   nov     -1  unknown
# 44124      no  45207       retired   no  divorced   nov     -1  unknown
# 44125      no  45208       retired   no   married   nov    184  success
# 44126      no  45209   blue-collar   no   married   nov     -1  unknown
# 44127      no  45210  entrepreneur   no   married   nov    188    other
#
#        previous subscribe
# 44123         0       NaN
# 44124         0       NaN
# 44125         3       NaN
# 44126         0       NaN
# 44127        11       NaN

# %% [markdown]
# ### numerical data visualization

# %%
# check distribution of each feature
f, ax = plt.subplots(len(numerical_list),1,figsize=(10,16))
f.tight_layout()
for i, cl in enumerate(numerical_list):
    g = sns.distplot(dataset[cl], color="m", label="Skewness : %.2f"%(dataset[cl].skew()), ax=ax[i])
    g = g.legend(loc="best")

# %%
skewedlist = ['balance','duration','campaign','day','previous']

# %%
dataset.describe()
# Out:
#                 age        balance      campaign           day      duration  \
# count  44128.000000   44128.000000  44128.000000  44128.000000  44128.000000
# mean      40.948083    1292.445545      2.755779     15.837133    253.784898
# std       10.654633    2964.924975      3.106873      8.349272    250.951467
# min       18.000000   -8019.000000      1.000000      1.000000      0.000000
# 25%       33.000000      68.000000      1.000000      8.000000    103.000000
# 50%       39.000000     434.000000      2.000000     16.000000    179.000000
# 75%       48.000000    1366.000000      3.000000     21.000000    315.000000
# max       95.000000  102127.000000     63.000000     31.000000   4918.000000
#
#               index         pdays      previous
# count  44128.000000  44128.000000  44128.000000
# mean   22363.440741     35.916833      0.515228
# std    13092.634464     96.163799      2.213530
# min        0.000000     -1.000000      0.000000
# 25%    11034.750000     -1.000000      0.000000
# 50%    22078.500000     -1.000000      0.000000
# 75%    33684.500000     -1.000000      0.000000
# max    45210.000000    871.000000    275.000000

# %%
# subscribe label encoding

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
train['subscribe'] = enc.fit_transform(train['subscribe'])
enc.classes_
# Out:
# array(['no', 'yes'], dtype=object)

# %%
g = sns.heatmap(train.corr(),annot=True,fmt='.2f',cmap='coolwarm')

# %%
g = sns.factorplot(x='age', y='subscribe', data=t, kind='bar',palette = 'muted')
g.despine(left=True)
g = g.set_ylabels('subscribe probability')

# %%
g = sns.factorplot(x='day', y='subscribe', data=t, kind='bar',palette = 'muted')
g.despine(left=True)
g = g.set_ylabels('subscribe probability')

# %%
g = sns.factorplot(x='campaign', y='subscribe', data=t, kind='bar',palette = 'muted')
g.despine(left=True)
g = g.set_ylabels('subscribe probability')

# %%
g = sns.FacetGrid(t, col='subscribe')
g = g.map(sns.distplot, "age")

# %% [markdown]
# ### Flatten skewed data

# %%
skewedlist = ['balance','duration','campaign','day','previous']

# %%
for cl in skewedlist:
    dataset[cl] = dataset[cl].map(lambda x : np.log(x) if x>0 else x)
    dataset[cl] = dataset[cl].map(lambda x : -np.log(-x) if x<0 else x)

# %%
# After scaling

# %%
# check distribution of each feature
f, ax = plt.subplots(len(numerical_list),1,figsize=(10,16))
f.tight_layout()
for i, cl in enumerate(numerical_list):
    g = sns.distplot(dataset[cl], color="m", label="Skewness : %.2f"%(dataset[cl].skew()), ax=ax[i])
    g = g.legend(loc="best")

# %% [markdown]
# ### Categorical Values

# %%
cate_list = ['job','marital','education','default','housing','loan','contact','month','poutcome']

# %%
# check distribution of each feature
f, ax = plt.subplots(len(cate_list),1,figsize=(10,16))
f.tight_layout()
for i, cl in enumerate(cate_list):
    g = sns.barplot(x=cl,y='subscribe', data=train, ax=ax[i])
    g = g.set_ylabel(cl+' Probaility')
