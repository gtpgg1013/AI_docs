# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 가장 쉬운 예제

list1 = np.random.rand(10)*2.1
list2 = np.random.rand(10)*3.0

plt.subplot(1, 2, 1)  # 1 line, 2 rows, index nr 1 (first position in the subplot)
plt.hist(list1)
plt.subplot(1, 2, 2)  # 1 line, 2 rows, index nr 2 (second position in the subplot)
plt.hist(list2)
plt.show()

# %%
# matplotlib in jupyter notebook : 간단!
fig = plt.figure(figsize=(10,6)) # 1. plt.figure객체(원판) 생성

# %%
# plt.gcf() # figure 객체에 대한 참조

# %%
ax1 = fig.add_subplot(2,2,1) # 2. subplot 3개 달아주고 : 2x2 중 1번쨰
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
fig # 3. 그냥 fig치면 확인 가능

# %%
# plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
from numpy import random
_ = ax1.hist(random.randn(100),bins=20,color='k',alpha=0.3)
# 3. 이런식으로 각 ax(subplot)에 넣어줘도 되고

# %%
# 4. 요런식으로 각 ax(subplot)에 넣어줘도 됨!
ax2.scatter(np.arange(30), np.arange(30) + 3 * random.randn(30))
ax3.plot(np.random.randn(50).cumsum(), 'k--')

# %%
fig

# %%
fig2, axes = plt.subplots(nrows=2,ncols=3,sharex=True,sharey=True)

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BA0C9B24E0>,
# ...
#       dtype=object)

# %%
# fig2 # 위 그림과 똑갇

# %%
fig.subplots_adjust(wspace=0,hspace=0) # 여백관리

# %%
fig # 일케해주면 w, h간격이 없어졌당

# %%
fig.subplots_adjust(wspace=0.2,hspace=0.2) # 겹치니까 다시 벌려줌

# %%
fig

# %%
ticks = ax1.set_xticks([-3,0,3])

# %%
fig # 바뀜

# %%
labels = ax1.set_xticklabels(['start','mid','end'], rotation=30, fontsize='small')

# %%
fig

# %%
ax1.set_title('ax1') # 이름지정
# Out:
# Text(0.5, 1.0, 'ax1')

# %%
ax1.set_xlabel('horizontal') # 라벨 이름지정
# Out:
# Text(0.5, 173.5612259113946, 'horizontal')

# %%
fig
fig.subplots_adjust(hspace=0.3) # 위아래 좀아서 좀 더 벌려줌

# %%
fig

# %%
# 범례
# ax3에 그래프 하나 더 추가
ax3.plot(np.random.randn(1000).cumsum(),'k',label='one')
ax3.plot(np.random.randn(1000).cumsum(),'k--',label='two')
ax3.plot(np.random.randn(1000).cumsum(),'k.',label='three')

# %%
fig

# %%
ax3.legend(loc='best') # 제일 좋은데 두겠다

# %%
fig
