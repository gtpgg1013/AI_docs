# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# OS
# !cat /etc/issue.net

# %%
# !head /proc/cpuinfo

# %%
# !head -n 3 /proc/meminfo

# %%
# !df -h

# %%
# !python --version

# %%
# !nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/MLpy/house_data_another/train.csv')

# %%
test = pd.read_csv('/content/drive/My Drive/Colab Notebooks/MLpy/house_data_another/test.csv')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6468 entries, 0 to 6467
# Data columns (total 20 columns):
# id               6468 non-null int64
# date             6468 non-null object
# bedrooms         6468 non-null int64
# bathrooms        6468 non-null float64
# sqft_living      6468 non-null int64
# sqft_lot         6468 non-null int64
# floors           6468 non-null float64
# waterfront       6468 non-null int64
# view             6468 non-null int64
# condition        6468 non-null int64
# grade            6468 non-null int64
# sqft_above       6468 non-null int64
# sqft_basement    6468 non-null int64
# yr_built         6468 non-null int64
# yr_renovated     6468 non-null int64
# zipcode          6468 non-null int64
# lat              6468 non-null float64
# long             6468 non-null float64
# sqft_living15    6468 non-null int64
# sqft_lot15       6468 non-null int64
# dtypes: float64(4), int64(15), object(1)
# memory usage: 1010.7+ KB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15035 entries, 0 to 15034
# Data columns (total 21 columns):
# id               15035 non-null int64
# date             15035 non-null object
# price            15035 non-null float64
# bedrooms         15035 non-null int64
# bathrooms        15035 non-null float64
# sqft_living      15035 non-null int64
# sqft_lot         15035 non-null int64
# floors           15035 non-null float64
# waterfront       15035 non-null int64
# view             15035 non-null int64
# condition        15035 non-null int64
# grade            15035 non-null int64
# sqft_above       15035 non-null int64
# sqft_basement    15035 non-null int64
# yr_built         15035 non-null int64
# yr_renovated     15035 non-null int64
# zipcode          15035 non-null int64
# lat              15035 non-null float64
# long             15035 non-null float64
# sqft_living15    15035 non-null int64
# sqft_lot15       15035 non-null int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 2.4+ MB

# %%
train.head()
# Out:
#    id             date     price  ...     long  sqft_living15  sqft_lot15
# 0   0  20141013T000000  221900.0  ... -122.257           1340        5650
# 1   1  20150225T000000  180000.0  ... -122.233           2720        8062
# 2   2  20150218T000000  510000.0  ... -122.045           1800        7503
# 3   3  20140627T000000  257500.0  ... -122.327           2238        6819
# 4   4  20150115T000000  291850.0  ... -122.315           1650        9711
#
# [5 rows x 21 columns]

# %%
train['datetime'] = train.date.str[:-7]

# %%
train['datetime'].head()
# Out:
# 0    20141013
# 1    20150225
# 2    20150218
# 3    20140627
# 4    20150115
# Name: datetime, dtype: object

# %%
train['datetime'] = pd.to_datetime(train['datetime'])
train['datetime'].head()
# Out:
# 0   2014-10-13
# 1   2015-02-25
# 2   2015-02-18
# 3   2014-06-27
# 4   2015-01-15
# Name: datetime, dtype: datetime64[ns]

# %%
train['year'] = train['datetime'].dt.year
train['month'] = train['datetime'].dt.month
train['day'] = train['datetime'].dt.day

# %%
test['datetime'] = test.date.str[:-7]
test['datetime'] = pd.to_datetime(test['datetime'])
test['year'] = test['datetime'].dt.year
test['month'] = test['datetime'].dt.month
test['day'] = test['datetime'].dt.day

# %%
train.head()
# Out:
#    id             date     price  bedrooms  ...   datetime  year  month  day
# 0   0  20141013T000000  221900.0         3  ... 2014-10-13  2014     10   13
# 1   1  20150225T000000  180000.0         2  ... 2015-02-25  2015      2   25
# 2   2  20150218T000000  510000.0         3  ... 2015-02-18  2015      2   18
# 3   3  20140627T000000  257500.0         3  ... 2014-06-27  2014      6   27
# 4   4  20150115T000000  291850.0         3  ... 2015-01-15  2015      1   15
#
# [5 rows x 25 columns]

# %%
test.head()
# Out:
#       id             date  bedrooms  bathrooms  ...   datetime  year  month  day
# 0  15035  20141209T000000         3       2.25  ... 2014-12-09  2014     12    9
# 1  15036  20141209T000000         4       3.00  ... 2014-12-09  2014     12    9
# 2  15037  20140512T000000         4       4.50  ... 2014-05-12  2014      5   12
# 3  15038  20150415T000000         3       1.00  ... 2015-04-15  2015      4   15
# 4  15039  20150312T000000         3       2.50  ... 2015-03-12  2015      3   12
#
# [5 rows x 24 columns]

# %%
train.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'datetime', 'year',
#        'month', 'day'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['id', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'datetime', 'year', 'month', 'day'],
#       dtype='object')

# %%
train.tail()
# Out:
#           id             date      price  bedrooms  ...   datetime  year  month  day
# 15030  15030  20141014T000000   610685.0         4  ... 2014-10-14  2014     10   14
# 15031  15031  20150326T000000  1007500.0         4  ... 2015-03-26  2015      3   26
# 15032  15032  20140521T000000   360000.0         3  ... 2014-05-21  2014      5   21
# 15033  15033  20150223T000000   400000.0         4  ... 2015-02-23  2015      2   23
# 15034  15034  20141015T000000   325000.0         2  ... 2014-10-15  2014     10   15
#
# [5 rows x 25 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15035 entries, 0 to 15034
# Data columns (total 25 columns):
# id               15035 non-null int64
# date             15035 non-null object
# price            15035 non-null float64
# bedrooms         15035 non-null int64
# bathrooms        15035 non-null float64
# sqft_living      15035 non-null int64
# sqft_lot         15035 non-null int64
# floors           15035 non-null float64
# waterfront       15035 non-null int64
# view             15035 non-null int64
# condition        15035 non-null int64
# grade            15035 non-null int64
# sqft_above       15035 non-null int64
# sqft_basement    15035 non-null int64
# yr_built         15035 non-null int64
# yr_renovated     15035 non-null int64
# zipcode          15035 non-null int64
# lat              15035 non-null float64
# long             15035 non-null float64
# sqft_living15    15035 non-null int64
# sqft_lot15       15035 non-null int64
# datetime         15035 non-null datetime64[ns]
# year             15035 non-null int64
# month            15035 non-null int64
# day              15035 non-null int64
# dtypes: datetime64[ns](1), float64(5), int64(18), object(1)
# memory usage: 2.9+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6468 entries, 0 to 6467
# Data columns (total 24 columns):
# id               6468 non-null int64
# date             6468 non-null object
# bedrooms         6468 non-null int64
# bathrooms        6468 non-null float64
# sqft_living      6468 non-null int64
# sqft_lot         6468 non-null int64
# floors           6468 non-null float64
# waterfront       6468 non-null int64
# view             6468 non-null int64
# condition        6468 non-null int64
# grade            6468 non-null int64
# sqft_above       6468 non-null int64
# sqft_basement    6468 non-null int64
# yr_built         6468 non-null int64
# yr_renovated     6468 non-null int64
# zipcode          6468 non-null int64
# lat              6468 non-null float64
# long             6468 non-null float64
# sqft_living15    6468 non-null int64
# sqft_lot15       6468 non-null int64
# datetime         6468 non-null datetime64[ns]
# year             6468 non-null int64
# month            6468 non-null int64
# day              6468 non-null int64
# dtypes: datetime64[ns](1), float64(4), int64(18), object(1)
# memory usage: 1.2+ MB

# %%
train_label = train['price']

# %%
train_label.head()
# Out:
# 0    221900.0
# 1    180000.0
# 2    510000.0
# 3    257500.0
# 4    291850.0
# Name: price, dtype: float64

# %%
# 이건 그냥 밸류값
train.sqft_living.head()
# Out:
# 0    1180
# 1     770
# 2    1680
# 3    1715
# 4    1060
# Name: sqft_living, dtype: int64

# %%
train.sqft_living.plot(kind='box')

# %%
train.bedrooms.value_counts()
# Out:
# 3     6835
# 4     4797
# 2     1931
# 5     1108
# 6      188
# 1      133
# 7       22
# 8       10
# 9        5
# 0        4
# 10       2
# Name: bedrooms, dtype: int64

# %%
train.bathrooms.value_counts()
# Out:
# 2.50    3748
# 1.00    2675
# 1.75    2112
# 2.25    1433
# 2.00    1357
# 1.50    1009
# 2.75     843
# 3.50     510
# 3.00     493
# 3.25     410
# 3.75     108
# 4.00     100
# 4.50      64
# 4.25      57
# 0.75      45
# 4.75      16
# 5.00      14
# 5.25      11
# 5.50       7
# 1.25       5
# 0.00       4
# 5.75       3
# 0.50       3
# 6.00       2
# 8.00       2
# 6.25       1
# 6.75       1
# 7.75       1
# 7.50       1
# Name: bathrooms, dtype: int64

# %%
train.sqft_lot.head()
# 그냥 밸류값
# Out:
# 0     5650
# 1    10000
# 2     8080
# 3     6819
# 4     9711
# Name: sqft_lot, dtype: int64

# %%
train.floors.value_counts()
# Out:
# 1.0    7361
# 2.0    5810
# 1.5    1330
# 3.0     417
# 2.5     113
# 3.5       4
# Name: floors, dtype: int64

# %%
train.waterfront.value_counts()
# Out:
# 0    14928
# 1      107
# Name: waterfront, dtype: int64

# %%
train.view.value_counts()
# Out:
# 0    13548
# 2      665
# 3      373
# 1      241
# 4      208
# Name: view, dtype: int64

# %%
train.condition.value_counts()
# Out:
# 3    9793
# 4    3956
# 5    1155
# 2     110
# 1      21
# Name: condition, dtype: int64

# %%
train.grade.value_counts()
# Out:
# 7     6228
# 8     4207
# 9     1855
# 6     1406
# 10     781
# 11     288
# 5      174
# 12      61
# 4       23
# 13       9
# 3        2
# 1        1
# Name: grade, dtype: int64

# %%
train.sqft_above.head()
# just values
# Out:
# 0    1180
# 1     770
# 2    1680
# 3    1715
# 4    1060
# Name: sqft_above, dtype: int64

# %%
train.sqft_basement.head()
# just values
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: sqft_basement, dtype: int64

# %%
train.yr_built.value_counts()
# 이건 카테고리인가 아닌가?
# Out:
# 2014    405
# 2006    325
# 2004    305
# 2005    302
# 2003    284
# 2007    281
# 1977    272
# 1978    265
# 1968    254
# 2008    247
# 1967    242
# 1979    235
# 1959    225
# 1990    225
# 1987    223
# 2001    221
# 1989    210
# 1954    209
# 1962    202
# 1947    193
# 1955    193
# 1969    192
# 1950    189
# 1988    185
# 1999    182
# 1994    181
# 1963    180
# 1976    169
# 1958    168
# 1960    166
#        ...
# 1945     66
# 1930     65
# 1916     62
# 1908     61
# 1906     60
# 1919     59
# 1900     59
# 1923     56
# 1912     52
# 1921     51
# 1911     50
# 1905     50
# 1931     49
# 1937     49
# 1907     44
# 1915     43
# 1913     43
# 1938     42
# 1917     42
# 1914     40
# 1904     36
# 1903     30
# 1936     29
# 2015     28
# 1932     24
# 1901     21
# 1933     20
# 1902     20
# 1935     19
# 1934     11
# Name: yr_built, Length: 116, dtype: int64

# %%
train[['datetime','yr_built']].head()
# 구매한 날짜 / 지어진 날짜
# Out:
#     datetime  yr_built
# 0 2014-10-13      1955
# 1 2015-02-25      1933
# 2 2015-02-18      1987
# 3 2014-06-27      1995
# 4 2015-01-15      1963

# %%
train.yr_renovated.value_counts()
# 재건축 안된 게 대부분
# Out:
# 0       14404
# 2014       71
# 2013       28
# 2003       25
# 2007       25
# 2000       25
# 2005       24
# 1990       18
# 2004       17
# 2006       17
# 2001       15
# 2009       15
# 1991       15
# 1989       15
# 2002       15
# 1998       14
# 1984       14
# 1995       14
# 1983       13
# 1994       13
# 1999       13
# 1985       13
# 2010       12
# 2008       11
# 1987       11
# 2015       11
# 1996       11
# 1988       10
# 1997       10
# 1992       10
#         ...
# 1986        7
# 1968        6
# 1977        6
# 1978        5
# 1963        4
# 1981        4
# 1975        4
# 1980        4
# 1970        4
# 1964        4
# 1955        3
# 1972        3
# 1965        3
# 1956        3
# 1969        3
# 1967        2
# 1974        2
# 1957        2
# 1958        2
# 1962        2
# 1971        2
# 1973        2
# 1948        1
# 1950        1
# 1945        1
# 1946        1
# 1954        1
# 1976        1
# 1944        1
# 1940        1
# Name: yr_renovated, Length: 65, dtype: int64

# %%
train.zipcode.value_counts()
# 이건 categorial로 해야할 듯
# Out:
# 98103    421
# 98038    420
# 98115    408
# 98052    408
# 98117    387
# 98034    382
# 98042    372
# 98118    350
# 98023    349
# 98059    345
# 98133    344
# 98006    341
# 98058    306
# 98155    303
# 98033    296
# 98074    295
# 98125    294
# 98053    284
# 98027    275
# 98056    274
# 98075    258
# 98126    251
# 98106    247
# 98144    240
# 98001    239
# 98092    232
# 98029    229
# 98116    226
# 98065    216
# 98199    213
#         ...
# 98008    189
# 98168    185
# 98055    185
# 98003    185
# 98072    181
# 98136    179
# 98112    177
# 98166    176
# 98105    174
# 98177    170
# 98045    159
# 98022    159
# 98077    149
# 98011    147
# 98108    136
# 98002    131
# 98019    131
# 98119    127
# 98005    115
# 98007    103
# 98188     91
# 98014     90
# 98032     85
# 98070     79
# 98109     78
# 98102     75
# 98010     63
# 98024     54
# 98148     44
# 98039     36
# Name: zipcode, Length: 70, dtype: int64

# %%
train.lat.head()
# just values
# Out:
# 0    47.5112
# 1    47.7379
# 2    47.6168
# 3    47.3097
# 4    47.4095
# Name: lat, dtype: float64

# %%
train.long.head()
# Out:
# 0   -122.257
# 1   -122.233
# 2   -122.045
# 3   -122.327
# 4   -122.315
# Name: long, dtype: float64

# %%
train.sqft_living15.head()
# Out:
# 0    1340
# 1    2720
# 2    1800
# 3    2238
# 4    1650
# Name: sqft_living15, dtype: int64

# %%
train.sqft_lot15.head()
# Out:
# 0    5650
# 1    8062
# 2    7503
# 3    6819
# 4    9711
# Name: sqft_lot15, dtype: int64

# %%
# 목적편부 price는 집을 구매한 시점의 가격 : 현재 가격 반영 x
# 집을 최근에 고쳤어도 집의 가격에는 영향을 주지 못한다?!?
train['price'].describe()
# Out:
# count    1.503500e+04
# mean     5.406827e+05
# std      3.715247e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
import seaborn as sns
f, ax = plt.subplots(figsize=(8,6))
sns.distplot(train['price'])
# 많이 한쪽으로 치우쳐있다

# %%
print('Skewness :{}'.format(train['price'].skew()))
print('Kurtosis :{}'.format(train['price'].kurt()))
# k는 첨도 : k가 3에 가까울 수록 정규분포에 가깝다
# Out:
# Skewness :4.290252396939529
# Kurtosis :40.15491919350329

# %%
import pandas as pd #Analysis 
import matplotlib.pyplot as plt #Visulization
import seaborn as sns #Visulization
import numpy as np #Analysis 
from scipy.stats import norm #Analysis 
from sklearn.preprocessing import StandardScaler #Analysis 
from scipy import stats #Analysis 
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline
import gc

fig = plt.figure(figsize=(10,7))
fig.add_subplot(1,2,1)
res = stats.probplot(train['price'], plot=plt)
fig.add_subplot(1,2,2)
res = stats.probplot(np.log1p(train['price']), plot=plt)

# %%
train['price'] = np.log1p(train['price'])
sns.distplot(train['price'])

# %%
import scipy as sp
cor_abs = abs(train.corr(method='spearman'))
cor_abs
# Out:
#                      id     price  bedrooms  ...      year     month       day
# id             1.000000  0.036892  0.013834  ...  0.013244  0.010136  0.002231
# price          0.036892  1.000000  0.350185  ...  0.009247  0.016561  0.021072
# bedrooms       0.013834  0.350185  1.000000  ...  0.003445  0.005709  0.010182
# bathrooms      0.111903  0.498989  0.523963  ...  0.020950  0.006675  0.008071
# sqft_living    0.043499  0.646482  0.649001  ...  0.018779  0.006739  0.006593
# sqft_lot       0.141132  0.080554  0.217457  ...  0.002423  0.003301  0.010297
# floors         0.173174  0.328674  0.233211  ...  0.020448  0.014813  0.008694
# waterfront     0.011775  0.113179  0.008354  ...  0.002041  0.006053  0.014859
# view           0.027046  0.291720  0.079330  ...  0.019611  0.018968  0.011505
# condition      0.108179  0.021520  0.017853  ...  0.040617  0.017469  0.000448
# grade          0.091820  0.662125  0.386833  ...  0.022527  0.009530  0.020974
# sqft_above     0.072526  0.547868  0.540893  ...  0.013953  0.007656  0.004932
# sqft_basement  0.043541  0.245304  0.229599  ...  0.005263  0.001038  0.009850
# yr_built       0.232404  0.097844  0.180364  ...  0.003526  0.001103  0.013070
# yr_renovated   0.029928  0.112381  0.020432  ...  0.019193  0.006807  0.016981
# zipcode        0.002220  0.009266  0.171497  ...  0.001202  0.000164  0.010486
# lat            0.001464  0.450692  0.022815  ...  0.030900  0.022052  0.012679
# long           0.006746  0.071757  0.195264  ...  0.006102  0.007845  0.005178
# sqft_living15  0.019945  0.573777  0.445933  ...  0.009397  0.002667  0.010301
# sqft_lot15     0.134385  0.065771  0.201626  ...  0.000680  0.006478  0.019006
# year           0.013244  0.009247  0.003445  ...  1.000000  0.801770  0.004329
# month          0.010136  0.016561  0.005709  ...  0.801770  1.000000  0.059914
# day            0.002231  0.021072  0.010182  ...  0.004329  0.059914  1.000000
#
# [23 rows x 23 columns]

# %%
cor_cols= cor_abs.nlargest(n=10, columns='price').index
cor_cols
# 높은거 10개뽑기
# Out:
# Index(['price', 'grade', 'sqft_living', 'sqft_living15', 'sqft_above',
#        'bathrooms', 'lat', 'bedrooms', 'floors', 'view'],
#       dtype='object')

# %%
np.array(sp.stats.spearmanr(train[cor_cols].values))[0]
# price와 corr이 높은 column 10개 뽑기
# Out:
# array([[ 1.00000000e+00,  6.62125256e-01,  6.46482431e-01,
#          5.73777345e-01,  5.47867765e-01,  4.98988916e-01,
#          4.50691696e-01,  3.50184916e-01,  3.28674116e-01,
#          2.91719516e-01],
#        [ 6.62125256e-01,  1.00000000e+00,  7.17799601e-01,
#          6.65039030e-01,  7.15099945e-01,  6.61112311e-01,
#          1.00037933e-01,  3.86833231e-01,  5.04506199e-01,
#          2.11468857e-01],
#        [ 6.46482431e-01,  7.17799601e-01,  1.00000000e+00,
#          7.48213636e-01,  8.46081041e-01,  7.48612310e-01,
#          2.55443864e-02,  6.49001466e-01,  4.08416554e-01,
#          2.27205439e-01],
#        [ 5.73777345e-01,  6.65039030e-01,  7.48213636e-01,
#          1.00000000e+00,  6.99157749e-01,  5.75235493e-01,
#          2.51542683e-02,  4.45932971e-01,  3.11335434e-01,
#          2.52132180e-01],
#        [ 5.47867765e-01,  7.15099945e-01,  8.46081041e-01,
#          6.99157749e-01,  1.00000000e+00,  6.95671508e-01,
#         -2.82371151e-02,  5.40892582e-01,  6.03085217e-01,
#          1.40010628e-01],
#        [ 4.98988916e-01,  6.61112311e-01,  7.48612310e-01,
#          5.75235493e-01,  6.95671508e-01,  1.00000000e+00,
#          7.64876360e-04,  5.23962817e-01,  5.52079506e-01,
#          1.50775709e-01],
#        [ 4.50691696e-01,  1.00037933e-01,  2.55443864e-02,
#          2.51542683e-02, -2.82371151e-02,  7.64876360e-04,
#          1.00000000e+00, -2.28146726e-02,  2.40919446e-02,
#         -2.46225196e-03],
#        [ 3.50184916e-01,  3.86833231e-01,  6.49001466e-01,
#          4.45932971e-01,  5.40892582e-01,  5.23962817e-01,
#         -2.28146726e-02,  1.00000000e+00,  2.33211229e-01,
#          7.93296368e-02],
#        [ 3.28674116e-01,  5.04506199e-01,  4.08416554e-01,
#          3.11335434e-01,  6.03085217e-01,  5.52079506e-01,
#          2.40919446e-02,  2.33211229e-01,  1.00000000e+00,
#          2.07039697e-02],
#        [ 2.91719516e-01,  2.11468857e-01,  2.27205439e-01,
#          2.52132180e-01,  1.40010628e-01,  1.50775709e-01,
#         -2.46225196e-03,  7.93296368e-02,  2.07039697e-02,
#          1.00000000e+00]])

# %%
cor = np.array(sp.stats.spearmanr(train[cor_cols].values))[0]

# %%
print(cor_cols.values)
# Out:
# ['price' 'grade' 'sqft_living' 'sqft_living15' 'sqft_above' 'bathrooms'
#  'lat' 'bedrooms' 'floors' 'view']

# %%
plt.figure(figsize=(10,10))
sns.set(font_scale=1.25)
sns.heatmap(cor, fmt='.2f', annot=True, square=True, annot_kws={'size':8},\
           xticklabels=cor_cols.values, yticklabels=cor_cols.values)

# %%
data = pd.concat([train['price'], train['grade']], axis=1)
f, ax = plt.subplots(figsize=(8,6))
fig = sns.boxplot(x='grade', y='price', data=data)

# %%
data = pd.concat([train['price'], train['sqft_living']], axis=1)
f, ax = plt.subplots(figsize=(8,6))
fig = sns.regplot(x='sqft_living', y='price', data=data)

# %%
data = pd.concat([train['price'], train['sqft_living15']], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.regplot(x='sqft_living15', y="price", data=data)

# %%
data = pd.concat([train['price'], train['sqft_above']], axis=1)
f, ax = plt.subplots(figsize=(8,6))
fig = sns.regplot(x='sqft_above', y='price', data=data)

# %%
data = pd.concat([train['price'], train['bathrooms']], axis=1)
data.head()
# Out:
#        price  bathrooms
# 0  12.309987       1.00
# 1  12.100718       1.00
# 2  13.142168       2.00
# 3  12.458779       2.25
# 4  12.583999       1.50

# %%
f, ax = plt.subplots(figsize=(12,6))
fig = sns.boxplot(x="bathrooms", y="price", data=data)

# %%
data = pd.concat([train['price'], train['bedrooms']], axis=1)
f, ax = plt.subplots(figsize=(12,6))
fig = sns.boxplot(x='bedrooms', y='price', data=data)

# %%
train['floors'].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %%
# 이상치 제거

data = pd.concat([train['price'], train['sqft_living']], axis=1)
f, ax = plt.subplots(figsize=(8,6))
fig = sns.regplot(x='sqft_living', y='price', data=data)

# %%
train.loc[train['sqft_living'] > 13000]
# Out:
#         id             date      price  bedrooms  ...   datetime  year  month  day
# 8912  8912  20140505T000000  14.639686         7  ... 2014-05-05  2014      5    5
#
# [1 rows x 25 columns]

# %%
train = train.loc[train['id']!=8912]

# %%
data = pd.concat([train['price'], train['grade']], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x='grade', y="price", data=data)

# %%
train.loc[(train['price']>12) & (train['grade'] == 3)]
# sqft
# Out:
#         id             date      price  bedrooms  ...   datetime  year  month  day
# 2302  2302  20150225T000000  12.476104         1  ... 2015-02-25  2015      2   25
# 4123  4123  20141104T000000  12.542548         1  ... 2014-11-04  2014     11    4
#
# [2 rows x 25 columns]

# %%
train[['grade','sqft_living','sqft_living15']].describe()
# 중요 변수인 grade, sqft 모두 위 두개는 낮은데 price는 높다? : 이상치
# Out:
#               grade   sqft_living  sqft_living15
# count  15034.000000  15034.000000    15034.00000
# mean       7.660436   2083.028203     1992.56472
# std        1.179311    917.418561      691.08662
# min        1.000000    290.000000      399.00000
# 25%        7.000000   1430.000000     1490.00000
# 50%        7.000000   1910.000000     1850.00000
# 75%        8.000000   2560.000000     2360.00000
# max       13.000000  12050.000000     6210.00000

# %%
train.loc[(train['price'] > 14.7) & (train['grade'] == 8)]
# Out:
#         id             date      price  bedrooms  ...   datetime  year  month  day
# 7173  7173  20140813T000000  14.808763         5  ... 2014-08-13  2014      8   13
#
# [1 rows x 25 columns]

# %%
train.loc[(train['price']>15.5) & (train['grade'] == 11)]
# Out:
#         id             date     price  bedrooms  ...   datetime  year  month  day
# 2775  2775  20140611T000000  15.77031         5  ... 2014-06-11  2014      6   11
#
# [1 rows x 25 columns]

# %%
train = train.loc[train['id']!=456]
train = train.loc[train['id']!=2302]
train = train.loc[train['id']!=4123]
train = train.loc[train['id']!=7259]
train = train.loc[train['id']!=2777]

# %%
data = pd.concat([train['price'], train['bedrooms']], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x='bedrooms', y="price", data=data)

# %%
f, ax = plt.subplots(12, 2, figsize=(10,20))

# id 변수 제외
count = 0
columns = ['price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15', 'year',
       'month', 'day']
for row in range(12):
    for col in range(2):
        sns.kdeplot(train[columns[count]], ax=ax[row][col])
        ax[row][col].set_title(columns[count], fontsize=15)
        count += 1
    if count == 20:
        break

# %%
# 치우친 넘 : bedrooms, bathrooms, sqft_living, sqft_lot, sqft_above, sqft_basement

# %%
skew_columns = ['bedrooms', \
                'bathrooms', 'sqft_living', 'sqft_lot'\
                , 'sqft_above', 'sqft_basement']

for c in skew_columns:
    train[c] = np.log1p(train[c].values)

f, ax = plt.subplots(3,2, figsize=(10,15))

count = 0
for row in range(3):
    for col in range(2):
        if count == 6:
            break
        sns.kdeplot(train[skew_columns[count]], ax=ax[row][col])
        ax[row][col].set_title(skew_columns[count], fontsize=15)
        count += 1

# %%
skew_columns = ['bedrooms', \
                'bathrooms', 'sqft_living', 'sqft_lot'\
                , 'sqft_above', 'sqft_basement']

for c in skew_columns:
    test[c] = np.log1p(test[c].values)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15029 entries, 0 to 15034
# Data columns (total 25 columns):
# id               15029 non-null int64
# date             15029 non-null object
# price            15029 non-null float64
# bedrooms         15029 non-null float64
# bathrooms        15029 non-null float64
# sqft_living      15029 non-null float64
# sqft_lot         15029 non-null float64
# floors           15029 non-null float64
# waterfront       15029 non-null int64
# view             15029 non-null int64
# condition        15029 non-null int64
# grade            15029 non-null int64
# sqft_above       15029 non-null float64
# sqft_basement    15029 non-null float64
# yr_built         15029 non-null int64
# yr_renovated     15029 non-null int64
# zipcode          15029 non-null int64
# lat              15029 non-null float64
# long             15029 non-null float64
# sqft_living15    15029 non-null int64
# sqft_lot15       15029 non-null int64
# datetime         15029 non-null datetime64[ns]
# year             15029 non-null int64
# month            15029 non-null int64
# day              15029 non-null int64
# dtypes: datetime64[ns](1), float64(10), int64(13), object(1)
# memory usage: 3.6+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6468 entries, 0 to 6467
# Data columns (total 24 columns):
# id               6468 non-null int64
# date             6468 non-null object
# bedrooms         6468 non-null float64
# bathrooms        6468 non-null float64
# sqft_living      6468 non-null float64
# sqft_lot         6468 non-null float64
# floors           6468 non-null float64
# waterfront       6468 non-null int64
# view             6468 non-null int64
# condition        6468 non-null int64
# grade            6468 non-null int64
# sqft_above       6468 non-null float64
# sqft_basement    6468 non-null float64
# yr_built         6468 non-null int64
# yr_renovated     6468 non-null int64
# zipcode          6468 non-null int64
# lat              6468 non-null float64
# long             6468 non-null float64
# sqft_living15    6468 non-null int64
# sqft_lot15       6468 non-null int64
# datetime         6468 non-null datetime64[ns]
# year             6468 non-null int64
# month            6468 non-null int64
# day              6468 non-null int64
# dtypes: datetime64[ns](1), float64(9), int64(13), object(1)
# memory usage: 1.2+ MB

# %%
for df in [train,test]:
    df['yr_renovated'] = df['yr_renovated'].apply(lambda x: np.nan if x == 0 else x)
    df['yr_renovated'] = df['yr_renovated'].fillna(df['yr_built'])

# %%
for df in [train,test]:
    df['date'] = df['date'].apply(lambda x : x[0:8])

# %%
train.head()
# Out:
#    id      date      price  bedrooms  ...   datetime  year  month  day
# 0   0  20141013  12.309987  1.386294  ... 2014-10-13  2014     10   13
# 1   1  20150225  12.100718  1.098612  ... 2015-02-25  2015      2   25
# 2   2  20150218  13.142168  1.386294  ... 2015-02-18  2015      2   18
# 3   3  20140627  12.458779  1.386294  ... 2014-06-27  2014      6   27
# 4   4  20150115  12.583999  1.386294  ... 2015-01-15  2015      1   15
#
# [5 rows x 25 columns]

# %%
for df in [train, test]:
    # 방 전체 갯수
    df['total_rooms'] = df['bedrooms'] + df['bathrooms']
    # 거실의 비율
    df['sqft_ratio'] = df['sqft_living'] / df['sqft_lot']
    df['sqft_total_size'] = df['sqft_above'] + df['sqft_basement']
    # 면적 대비 거실의 비율
    df['sqft_ratio_1'] = df['sqft_living'] / df['sqft_total_size']
    df['sqft_ratio15'] = df['sqft_living15'] / df['sqft_lot15']
    # 재건축 여부
    df['is_renovated'] = df['yr_renovated'] - df['yr_built']
    df['is_renovated'] = df['is_renovated'].apply(lambda x : 0 if x==0 else 1)
    df['date'] = df['date'].astype('int')

# %%
# zipcode 이용해서 feature engineering

train['per_price'] = train['price'] / train['sqft_total_size']
zipcode_price = train.groupby(['zipcode'])['per_price']\
            .agg({'mean','var'}).reset_index()

# %%
zipcode_price.head()
# Out:
#    zipcode      mean       var
# 0    98001  1.490736  0.110772
# 1    98002  1.559377  0.086592
# 2    98003  1.426763  0.135985
# 3    98004  1.425458  0.174417
# 4    98005  1.307652  0.162820

# %%
train = pd.merge(train, zipcode_price, how='left', on='zipcode')
test = pd.merge(test, zipcode_price, how='left', on='zipcode')

for df in [train, test]:
    df['zipcode_mean'] = df['mean'] * df['sqft_total_size']
    df['zipcode_var'] = df['var'] * df['sqft_total_size']
    del df['mean']
    del df['var']

# %%
train.head()
# Out:
#    id      date      price  ...  per_price  zipcode_mean  zipcode_var
# 0   0  20141013  12.309987  ...   1.740145      9.368147     1.214207
# 1   1  20150225  12.100718  ...   1.820290      9.257745     1.023549
# 2   2  20150218  13.142168  ...   1.769478     11.307711     0.826257
# 3   3  20140627  12.458779  ...   1.672824     10.626177     1.012780
# 4   4  20150115  12.583999  ...   1.806238     10.032009     1.002206
#
# [5 rows x 34 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15029 entries, 0 to 15028
# Data columns (total 34 columns):
# id                 15029 non-null int64
# date               15029 non-null int64
# price              15029 non-null float64
# bedrooms           15029 non-null float64
# bathrooms          15029 non-null float64
# sqft_living        15029 non-null float64
# sqft_lot           15029 non-null float64
# floors             15029 non-null float64
# waterfront         15029 non-null int64
# view               15029 non-null int64
# condition          15029 non-null int64
# grade              15029 non-null int64
# sqft_above         15029 non-null float64
# sqft_basement      15029 non-null float64
# yr_built           15029 non-null int64
# yr_renovated       15029 non-null float64
# zipcode            15029 non-null int64
# lat                15029 non-null float64
# long               15029 non-null float64
# sqft_living15      15029 non-null int64
# sqft_lot15         15029 non-null int64
# datetime           15029 non-null datetime64[ns]
# year               15029 non-null int64
# month              15029 non-null int64
# day                15029 non-null int64
# total_rooms        15029 non-null float64
# sqft_ratio         15029 non-null float64
# sqft_total_size    15029 non-null float64
# sqft_ratio_1       15029 non-null float64
# sqft_ratio15       15029 non-null float64
# is_renovated       15029 non-null int64
# per_price          15029 non-null float64
# zipcode_mean       15029 non-null float64
# zipcode_var        15029 non-null float64
# dtypes: datetime64[ns](1), float64(19), int64(14)
# memory usage: 4.0 MB

# %%
train.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'datetime', 'year',
#        'month', 'day', 'total_rooms', 'sqft_ratio', 'sqft_total_size',
#        'sqft_ratio_1', 'sqft_ratio15', 'is_renovated', 'per_price',
#        'zipcode_mean', 'zipcode_var'],
#       dtype='object')

# %%
cols_train = ['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15', 
       'total_rooms', 'sqft_ratio', 'sqft_total_size',
       'sqft_ratio_1', 'sqft_ratio15', 'is_renovated',
       'zipcode_mean', 'zipcode_var']

# %%
train[cols_train].describe()
# Out:
#            bedrooms     bathrooms  ...  zipcode_mean   zipcode_var
# count  15029.000000  15029.000000  ...  15029.000000  15029.000000
# mean       1.452970      1.105507  ...     14.125610      1.382602
# std        0.210576      0.250586  ...      4.211421      0.620996
# min        0.000000      0.000000  ...      7.679645      0.296675
# 25%        1.386294      1.011601  ...     10.643946      0.928701
# 50%        1.386294      1.178655  ...     12.068375      1.197693
# 75%        1.609438      1.252763  ...     18.409966      2.032193
# max        2.397895      2.197225  ...     25.991591      2.963357
#
# [8 rows x 26 columns]

# %%
train[cols_train].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15029 entries, 0 to 15028
# Data columns (total 26 columns):
# bedrooms           15029 non-null float64
# bathrooms          15029 non-null float64
# sqft_living        15029 non-null float64
# sqft_lot           15029 non-null float64
# floors             15029 non-null float64
# waterfront         15029 non-null int64
# view               15029 non-null int64
# condition          15029 non-null int64
# grade              15029 non-null int64
# sqft_above         15029 non-null float64
# sqft_basement      15029 non-null float64
# yr_built           15029 non-null int64
# yr_renovated       15029 non-null float64
# zipcode            15029 non-null int64
# lat                15029 non-null float64
# long               15029 non-null float64
# sqft_living15      15029 non-null int64
# sqft_lot15         15029 non-null int64
# total_rooms        15029 non-null float64
# sqft_ratio         15029 non-null float64
# sqft_total_size    15029 non-null float64
# sqft_ratio_1       15029 non-null float64
# sqft_ratio15       15029 non-null float64
# is_renovated       15029 non-null int64
# zipcode_mean       15029 non-null float64
# zipcode_var        15029 non-null float64
# dtypes: float64(17), int64(9)
# memory usage: 3.1 MB

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

rScaler = RobustScaler()
sScaler = StandardScaler()
mScaler = MinMaxScaler()
rScaler.fit_transform(train[cols_train])
# Out:
# array([[ 0.        , -2.01320151, -0.82688149, ...,  0.        ,
#         -0.3476978 ,  0.01496545],
#        [-1.28922423, -2.01320151, -1.55954581, ...,  0.        ,
#         -0.36191386, -0.1578112 ],
#        [ 0.        , -0.33190423, -0.22033068, ...,  0.        ,
#         -0.0979478 , -0.33659995],
#        ...,
#        [ 0.        ,  0.30729532, -0.38092146, ...,  0.        ,
#         -0.13259199,  0.00460435],
#        [ 1.        ,  0.30729532,  0.32653905, ...,  0.        ,
#         -0.09979286, -0.02194453],
#        [-1.28922423, -2.56690135, -1.07700678, ...,  0.        ,
#         -0.42364838, -0.09083226]])

# %%
mScaler.fit_transform(train[cols_train])
# Out:
# array([[0.57812965, 0.31546488, 0.3761954 , ..., 0.        , 0.0922077 ,
#         0.34407248],
#        [0.45815691, 0.31546488, 0.2616743 , ..., 0.        , 0.08617872,
#         0.27257629],
#        [0.57812965, 0.5       , 0.47100399, ..., 0.        , 0.19812563,
#         0.19859225],
#        ...,
#        [0.57812965, 0.570157  , 0.44590241, ..., 0.        , 0.18343317,
#         0.33978498],
#        [0.67118774, 0.570157  , 0.55648396, ..., 0.        , 0.19734315,
#         0.32879887],
#        [0.45815691, 0.25469212, 0.33709889, ..., 0.        , 0.05999737,
#         0.30029264]])

# %%
sScaler.fit_transform(train[cols_train])
# Out:
# array([[-0.31664504, -1.64563658, -1.12491032, ..., -0.20917227,
#         -1.12969501, -0.27117818],
#        [-1.68285783, -1.64563658, -2.12787525, ..., -0.20917227,
#         -1.15591084, -0.5782073 ],
#        [-0.31664504, -0.02751484, -0.29458573, ..., -0.20917227,
#         -0.6691312 , -0.8959201 ],
#        ...,
#        [-0.31664504,  0.5876665 , -0.51442299, ..., -0.20917227,
#         -0.73301853, -0.28959014],
#        [ 0.74307192,  0.5876665 ,  0.45403974, ..., -0.20917227,
#         -0.67253367, -0.33676827],
#        [-1.68285783, -2.1785309 , -1.46731391, ..., -0.20917227,
#         -1.26975543, -0.45918378]])

# %%
# cols_category = ['bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'year',
#        'month', 'day', 'total_rooms', 'sqft_ratio', 'sqft_total_size',
#        'sqft_ratio_1', 'sqft_ratio15', 'is_renovated', 'per_price',
#        'zipcode_mean', 'zipcode_var']

# %%
train_label = train['price']
train_label = train_label.values.reshape(-1,1)
train_label.shape
# Out:
# (15029, 1)

# %%
train[['price']]
# Out:
#            price
# 0      12.309987
# 1      12.100718
# 2      13.142168
# 3      12.458779
# 4      12.583999
# 5      13.403777
# 6      13.056226
# 7      12.644331
# 8      12.899222
# 9      13.180634
# 10     13.384729
# 11     12.886644
# 12     13.091906
# 13     12.149508
# 14     12.345839
# 15     12.861001
# 16     14.508658
# 17     12.439962
# 18     12.703816
# 19     12.358798
# 20     13.750440
# 21     13.410547
# 22     13.271647
# 23     13.440819
# 24     13.190024
# 25     12.683862
# 26     13.453106
# 27     13.369225
# 28     12.388398
# 29     13.312985
# ...          ...
# 14999  12.706851
# 15000  13.318754
# 15001  13.573440
# 15002  13.322772
# 15003  12.899097
# 15004  13.269059
# 15005  12.800783
# 15006  13.377007
# 15007  13.296093
# 15008  13.102163
# 15009  12.899097
# 15010  12.506181
# 15011  13.132316
# 15012  12.861001
# 15013  12.934831
# 15014  12.758523
# 15015  14.016409
# 15016  13.899853
# 15017  12.765691
# 15018  13.429776
# 15019  14.269766
# 15020  13.604791
# 15021  14.245344
# 15022  13.054087
# 15023  13.136761
# 15024  13.322338
# 15025  13.822984
# 15026  12.793862
# 6447  1.386294   1.011601     7.409136  ...             0      9.171407     1.051862
# 6448  1.609438   1.252763     7.775276  ...             0     10.498495     1.110330
# 6449  1.386294   1.252763     8.016648  ...             0     12.465411     0.696880
# 6450  1.386294   1.098612     7.139660  ...             0     17.441802     2.206553
# 6451  1.386294   1.252763     7.252054  ...             0     15.990008     1.908490
# 6452  1.386294   1.252763     7.654917  ...             0     19.233580     2.328561
# 6453  1.609438   1.386294     7.421178  ...             0     16.972869     2.172334
# 6454  1.098612   1.252763     6.888572  ...             0      9.426398     1.221862
# 6455  1.386294   1.011601     7.039660  ...             0      9.005409     1.152394
# 6456  1.791759   1.704748     8.486940  ...             0     21.584618     2.493704
# 6457  1.386294   1.386294     7.930566  ...             0     12.571391     0.567928
# 6458  1.386294   1.252763     7.139660  ...             0     16.233850     2.056584
# 6459  1.609438   1.321756     7.926964  ...             0     10.497559     1.360590
# 6460  1.386294   1.178655     7.082549  ...             0     10.660665     1.161587
# 6461  1.098612   1.178655     7.333676  ...             0     16.906876     1.842174
# 6462  1.609438   1.252763     8.045268  ...             0     11.993373     0.891187
# 6463  1.386294   1.011601     7.313887  ...             0     11.526568     0.619162
# 6464  1.386294   1.098612     7.307202  ...             0      9.258074     1.157439
# 6465  1.386294   1.252763     7.178545  ...             0     15.373075     1.947537
# 6466  1.098612   0.559616     6.928538  ...             0      8.778314     1.097460
# 6467  1.386294   1.252763     7.378384  ...             0      9.724217     1.121004
#
# [6468 rows x 26 columns]

# %%
xdata = mScaler.fit_transform(train[cols_train])
ydata = train_label

# %%
xdata.shape
# Out:
# (15029, 26)

# %%
ydata.shape
# Out:
# (15029, 1)

# %%
x_real_data.shape
# Out:
# (6468, 26)

# %%
x_real_data
# Out:
#       bedrooms  bathrooms  sqft_living  ...  is_renovated  zipcode_mean  zipcode_var
# 0     1.386294   1.178655     7.852050  ...             1     19.243241     2.317027
# 1     1.609438   1.386294     7.581210  ...             0     18.113257     2.389816
# 2     1.609438   1.704748     8.598036  ...             0     25.917920     0.737584
# 3     1.386294   0.693147     7.484930  ...             0     19.759625     2.053191
# 4     1.386294   1.252763     7.544861  ...             0     11.947244     0.477170
# 5     1.791759   1.252763     7.727976  ...             0     11.812116     0.663187
# 6     1.386294   1.011601     7.327123  ...             0     17.129307     2.206809
# 7     1.609438   1.252763     7.852050  ...             0     11.480668     1.079471
# 8     1.098612   0.916291     7.082549  ...             0     10.405365     1.129948
# 9     1.609438   0.693147     7.415175  ...             0     19.637304     1.846399
# 10    1.609438   1.252763     7.852050  ...             0     11.954624     0.873528
# 11    1.386294   0.693147     7.155396  ...             0     18.332307     1.654500
# 12    1.386294   1.252763     8.058644  ...             0     12.464453     0.767080
# 13    1.386294   1.011601     7.131699  ...             0      9.207394     1.186210
# 14    1.386294   1.252763     7.920810  ...             0     22.095683     1.838438
# 15    1.386294   0.693147     7.082549  ...             0     10.893431     0.787128
# 16    1.791759   1.252763     8.055475  ...             0     22.261663     1.834610
# 17    1.098612   1.011601     7.591357  ...             0     18.880553     2.447322
# 15009  1.098612   0.693147  ...      8.793231     1.130623
# 15010  1.386294   1.252763  ...     11.733186     0.618278
# 15011  1.098612   1.252763  ...     10.542808     1.250389
# 15012  1.386294   1.252763  ...     10.309175     1.241300
# 15013  1.098612   0.916291  ...     16.668355     2.160574
# 15014  1.386294   1.252763  ...     12.415090     0.495856
# 15015  1.609438   1.504077  ...     23.657575     1.728665
# 15016  1.791759   1.558145  ...     12.603670     1.038684
# 15017  1.609438   1.321756  ...     12.185147     0.642094
# 15018  1.791759   1.321756  ...     12.733356     0.711860
# 15019  1.609438   1.446919  ...     10.674815     1.319925
# 15020  1.609438   1.386294  ...     13.775948     0.392042
# 15021  1.791759   1.558145  ...     11.981494     1.466042
# 15022  1.386294   1.252763  ...     10.218431     1.230374
# 15023  1.386294   1.252763  ...     12.250249     0.553420
# 15024  1.609438   1.252763  ...     11.842391     0.975946
# 15025  1.609438   1.504077  ...     19.305049     2.547057
# 15026  1.386294   1.252763  ...     11.038663     1.202774
# 15027  1.609438   1.252763  ...     11.293382     1.173477
# 15028  1.098612   0.559616  ...      8.778314     1.097460
#
# [15029 rows x 26 columns]

# %%
xdata_raw_val = xdata_raw.values
xdata_raw_val
# Out:
# array([[ 1.38629436,  0.69314718,  7.07411682, ...,  0.        ,
#          9.3681473 ,  1.21420689],
#        [ 1.09861229,  0.69314718,  6.64768837, ...,  0.        ,
#          9.25774506,  1.02354934],
#        [ 1.38629436,  1.09861229,  7.42714413, ...,  0.        ,
#         11.30771075,  0.82625748],
#        ...,
#        [ 1.38629436,  1.25276297,  7.3336764 , ...,  0.        ,
#         11.03866329,  1.20277351],
#        [ 1.60943791,  1.25276297,  7.74543561, ...,  0.        ,
#         11.29338199,  1.17347705],
#        [ 1.09861229,  0.55961579,  6.92853782, ...,  0.        ,
#          8.77831356,  1.09746002]])

# %%
ydata_val = ydata

# %%
x_real_data_val = x_real_data

# %%
type(xtrain)
# Out:
# numpy.ndarray

# %%
type(ytrain)
# Out:
# numpy.ndarray

# %%
type(xtest)
# Out:
# numpy.ndarray

# %%
type(ytest)
# Out:
# numpy.ndarray

# %%
pred = None

# %%
x = tf.placeholder(dtype=tf.float32, shape=[None,29])
y = tf.placeholder(dtype=tf.float32, shape=[None,1])
w1 = tf.Variable(tf.random_normal([29,20]))
b1 = tf.Variable(tf.random_normal([20]))
hl1 = tf.nn.relu(tf.matmul(x,w1) + b1)

w2 = tf.Variable(tf.random_normal([20,20]))
b2 = tf.Variable(tf.random_normal([20]))
hl2 = tf.nn.relu(tf.matmul(hl1,w2) + b2)

w3 = tf.Variable(tf.random_normal([20,20]))
b3 = tf.Variable(tf.random_normal([20]))
hl3 = tf.nn.relu(tf.matmul(hl2,w3) + b3)

w4 = tf.Variable(tf.random_normal([20,10]))
b4 = tf.Variable(tf.random_normal([10]))
hl4 = tf.nn.relu(tf.matmul(hl3,w4) + b4)

w5 = tf.Variable(tf.random_normal([10,1]))
b5 = tf.Variable(tf.random_normal([1]))
hf = tf.matmul(hl4,w5) + b5

cost = tf.reduce_mean(tf.square(hf-y))
train_ = tf.train.AdamOptimizer(0.1).minimize(cost)

# %%
with tf.Session() as sess:
    init = tf.global_variables_initializer()
    sess.run(init)
    for step in range(2001):
        sess.run(train_, feed_dict={x:xtrain,y:ytrain})
        if step%200==0:
            print("cost : {}".format(sess.run(cost, feed_dict={x:xtrain,y:ytrain})))
    pred = sess.run(hf, feed_dict={x:xtest})

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(ytest, pred)
print(mse)

# %%
training = tf.placeholder_with_defalut(False, shape=())

x = tf.placeholder(dtype=tf.float32, shape=[None,29])
y = tf.placeholder(dtype=tf.float32, shape=[None,1])
w1 = tf.Variable(tf.random_normal([29,500], seed=1))
b1 = tf.Variable(tf.random_normal([500], seed=1))
hl1 = tf.nn.relu(tf.matmul(x,w1) + b1)

w2 = tf.Variable(tf.random_normal([500,500], seed=1))
b2 = tf.Variable(tf.random_normal([500], seed=1))
hl2 = tf.nn.relu(tf.matmul(hl1,w2) + b2)

w3 = tf.Variable(tf.random_normal([500,500], seed=1))
b3 = tf.Variable(tf.random_normal([500], seed=1))
hl3 = tf.nn.relu(tf.matmul(hl2,w3) + b3)

w4 = tf.Variable(tf.random_normal([500,50], seed=1))
b4 = tf.Variable(tf.random_normal([50], seed=1))
hl4 = tf.nn.relu(tf.matmul(hl3,w4) + b4)

w5 = tf.Variable(tf.random_normal([50,25], seed=1))
b5 = tf.Variable(tf.random_normal([25], seed=1))
hl5 = tf.nn.relu(tf.matmul(hl4,w5) + b5)

w6 = tf.Variable(tf.random_normal([25,1], seed=1))
b6 = tf.Variable(tf.random_normal([1], seed=1))
hf = tf.matmul(hl5,w6) + b6

cost = tf.reduce_mean(tf.square(hf-y))
train_ = tf.train.AdamOptimizer(0.1).minimize(cost)

# %%
with tf.Session() as sess:
    init = tf.global_variables_initializer()
    sess.run(init)
    for step in range(6001):
        sess.run(train_, feed_dict={x:xtrain,y:ytrain})
        if step%600==0:
            print("cost : {}".format(sess.run(cost, feed_dict={x:xdata,y:ydata})))
    pred = sess.run(hf, feed_dict={x:x_real_data})

# %%
pd.DataFrame(pred).head()

# %%
print(pred.min(), pred.max(), pred.mean())

# %%
pd.DataFrame(train_label).head()

# %%
train_label
# Out:
# array([[12.30998662],
#        [12.10071769],
#        [13.14216797],
#        ...,
#        [12.79386209],
#        [12.89922233],
#        [12.69158354]])

# %%
xdata_for_nn = xdata_raw.copy()
xdata_for_nn.head()
# Out:
#    bedrooms  bathrooms  sqft_living  ...  is_renovated  zipcode_mean  zipcode_var
# 0  1.386294   0.693147     7.074117  ...             0      9.368147     1.214207
# 1  1.098612   0.693147     6.647688  ...             0      9.257745     1.023549
# 2  1.386294   1.098612     7.427144  ...             0     11.307711     0.826257
# 3  1.386294   1.178655     7.447751  ...             0     10.626177     1.012780
# 4  1.386294   0.916291     6.966967  ...             0     10.032009     1.002206
#
# [5 rows x 26 columns]

# %%
x_real_data_for_nn = x_real_data.copy()
x_real_data_for_nn.head()
# Out:
#    bedrooms  bathrooms  sqft_living  ...  is_renovated  zipcode_mean  zipcode_var
# 0  1.386294   1.178655     7.852050  ...             1     19.243241     2.317027
# 1  1.609438   1.386294     7.581210  ...             0     18.113257     2.389816
# 2  1.609438   1.704748     8.598036  ...             0     25.917920     0.737584
# 3  1.386294   0.693147     7.484930  ...             0     19.759625     2.053191
# 4  1.386294   1.252763     7.544861  ...             0     11.947244     0.477170
#
# [5 rows x 26 columns]

# %%
xdata_for_nn.shape
# Out:
# (15029, 26)

# %%
x_real_data_for_nn.shape
# Out:
# (6468, 26)

# %%
xdata_for_nn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15029 entries, 0 to 15028
# Data columns (total 26 columns):
# bedrooms           15029 non-null float64
# bathrooms          15029 non-null float64
# sqft_living        15029 non-null float64
# sqft_lot           15029 non-null float64
# floors             15029 non-null category
# waterfront         15029 non-null category
# view               15029 non-null category
# condition          15029 non-null category
# grade              15029 non-null category
# sqft_above         15029 non-null float64
# sqft_basement      15029 non-null float64
# yr_built           15029 non-null int64
# yr_renovated       15029 non-null category
# zipcode            15029 non-null category
# lat                15029 non-null float64
# long               15029 non-null float64
# sqft_living15      15029 non-null int64
# sqft_lot15         15029 non-null int64
# total_rooms        15029 non-null category
# sqft_ratio         15029 non-null float64
# sqft_total_size    15029 non-null float64
# sqft_ratio_1       15029 non-null float64
# sqft_ratio15       15029 non-null float64
# is_renovated       15029 non-null category
# zipcode_mean       15029 non-null float64
# zipcode_var        15029 non-null float64
# dtypes: category(9), float64(14), int64(3)
# memory usage: 2.2 MB

# %%
x_real_data_for_nn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6468 entries, 0 to 6467
# Data columns (total 26 columns):
# bedrooms           6468 non-null float64
# bathrooms          6468 non-null float64
# sqft_living        6468 non-null float64
# sqft_lot           6468 non-null float64
# floors             6468 non-null category
# waterfront         6468 non-null category
# view               6468 non-null category
# condition          6468 non-null category
# grade              6468 non-null category
# sqft_above         6468 non-null float64
# sqft_basement      6468 non-null float64
# yr_built           6468 non-null int64
# yr_renovated       6468 non-null category
# zipcode            6468 non-null category
# lat                6468 non-null float64
# long               6468 non-null float64
# sqft_living15      6468 non-null int64
# sqft_lot15         6468 non-null int64
# total_rooms        6468 non-null category
# sqft_ratio         6468 non-null float64
# sqft_total_size    6468 non-null float64
# sqft_ratio_1       6468 non-null float64
# sqft_ratio15       6468 non-null float64
# is_renovated       6468 non-null category
# zipcode_mean       6468 non-null float64
# zipcode_var        6468 non-null float64
# dtypes: category(9), float64(14), int64(3)
# memory usage: 979.8 KB

# %%
xdata
# Out:
# array([[0.57812965, 0.31546488, 0.3761954 , ..., 0.        , 0.0922077 ,
#         0.34407248],
#        [0.45815691, 0.31546488, 0.2616743 , ..., 0.        , 0.08617872,
#         0.27257629],
#        [0.57812965, 0.5       , 0.47100399, ..., 0.        , 0.19812563,
#         0.19859225],
#        ...,
#        [0.57812965, 0.570157  , 0.44590241, ..., 0.        , 0.18343317,
#         0.33978498],
#        [0.67118774, 0.570157  , 0.55648396, ..., 0.        , 0.19734315,
#         0.32879887],
#        [0.45815691, 0.25469212, 0.33709889, ..., 0.        , 0.05999737,
#         0.30029264]])

# %%
xdata_for_nn.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'total_rooms', 'sqft_ratio',
#        'sqft_total_size', 'sqft_ratio_1', 'sqft_ratio15', 'is_renovated',
#        'zipcode_mean', 'zipcode_var'],
#       dtype='object')

# %%
catlist = ['floors', 'waterfront', 'view', 'condition', 'grade', 'is_renovated']

# %%
for cat in catlist:
  print(xdata_for_nn[cat].value_counts())
  print(x_real_data_for_nn[cat].value_counts())
# Out:
# 1.0    7357
# 2.0    5809
# 1.5    1330
# 3.0     416
# 2.5     113
# 3.5       4
# Name: floors, dtype: int64
# 1.0    3251
# 2.0    2406
# 1.5     565
# 3.0     194
# 2.5      48
# 3.5       4
# Name: floors, dtype: int64
# 0    14922
# 1      107
# Name: waterfront, dtype: int64
# 0    6412
# 1      56
# Name: waterfront, dtype: int64
# 0    13543
# 2      665
# 3      373
# 1      241
# 4      207
# Name: view, dtype: int64
# 0    5837
# 2     297
# 3     134
# 4     109
# 1      91
# Name: view, dtype: int64
# 3    9790
# 4    3955
# 5    1154
# 2     109
# 1      21
# Name: condition, dtype: int64
# 3    4168
# 4    1701
# 5     534
# 2      57
# 1       8
# Name: condition, dtype: int64
# 7     6226
# 8     4207
# 9     1854
# 6     1406
# 10     781
# 11     288
# 5      174
# 12      60
# 4       23
# 13       9
# 1        1
# Name: grade, dtype: int64
# 7     2701
# 8     1843
# 9      754
# 6      611
# 10     350
# 11     108
# 5       62
# 12      28
# 4        6
# 13       4
# 3        1
# Name: grade, dtype: int64
# 0    14399
# 1      630
# Name: is_renovated, dtype: int64
# 0    6186
# 1     282
# Name: is_renovated, dtype: int64

# %%
for df in [xdata_for_nn, x_real_data_for_nn]:
  for cat in catlist:
    df[cat] = df[cat].astype('category')

# %%
xdata_for_nn_input = pd.get_dummies(xdata_for_nn).values
x_real_data_for_nn_input = pd.get_dummies(x_real_data_for_nn).values

# %%
x_real_data_for_nn_input.shape
# Out:
# (6468, 51)

# %%
xdata_for_nn_input.shape
# Out:
# (15029, 51)

# %%
training = tf.placeholder_with_default(False, shape=())

x = tf.placeholder(dtype=tf.float32, shape=[None,51])
y = tf.placeholder(dtype=tf.float32, shape=[None,1])
dropout_rate = tf.placeholder("float")

w1 = tf.Variable(tf.random_normal([51,200], seed=1))
b1 = tf.Variable(tf.random_normal([200], seed=1))
hl1 = tf.matmul(x,w1) + b1
bl1 = tf.layers.batch_normalization(hl1, training=training, momentum=0.9)
bn1_act = tf.nn.relu(bl1)
bn1_act_ = tf.nn.dropout(bn1_act, dropout_rate)

w2 = tf.Variable(tf.random_normal([200,200], seed=1))
b2 = tf.Variable(tf.random_normal([200], seed=1))
hl2 = tf.matmul(bn1_act_,w2) + b2
bl2 = tf.layers.batch_normalization(hl2, training=training, momentum=0.9)
bn2_act = tf.nn.relu(bl2)
bn2_act_ = tf.nn.dropout(bn2_act, dropout_rate)

w3 = tf.Variable(tf.random_normal([200,100], seed=1))
b3 = tf.Variable(tf.random_normal([100], seed=1))
hl3 = tf.matmul(bn2_act_,w3) + b3
bl3 = tf.layers.batch_normalization(hl3, training=training, momentum=0.9)
bn3_act = tf.nn.relu(bl3)
bn3_act_ = tf.nn.dropout(bn3_act, dropout_rate)

w4 = tf.Variable(tf.random_normal([100,20], seed=1))
b4 = tf.Variable(tf.random_normal([20], seed=1))
hl4 = tf.matmul(bn3_act_,w4) + b4
bl4 = tf.layers.batch_normalization(hl4, training=training, momentum=0.9)
bn4_act = tf.nn.relu(bl4)
bn4_act_ = tf.nn.dropout(bn4_act, dropout_rate)

w5 = tf.Variable(tf.random_normal([20,1], seed=1))
b5 = tf.Variable(tf.random_normal([1], seed=1))
hf = tf.matmul(bn4_act_,w5) + b5

cost = tf.reduce_mean(tf.square(hf-y))
train_ = tf.train.AdamOptimizer(0.1).minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

training_epochs = 500
batch_size = 300
for epoch in range(training_epochs):
  np.random.shuffle(xdata_for_nn_input)
  total_batch = int(xdata_for_nn_input.shape[0] / batch_size)
  for batch_index in range(total_batch):
    start = batch_index * batch_size
    end = start + batch_size
    xdata_batch = xdata_for_nn_input[start:end]
    ydata_batch = ydata[start:end]
    sess.run(train_, feed_dict={x:xdata_batch,y:ydata_batch,dropout_rate:0.5})
  print("epoch : {}".format(epoch+1))
  print("cost : {}".format(sess.run(cost, feed_dict={x:xdata_for_nn_input,y:ydata,dropout_rate:1})))
pred = sess.run(hf, feed_dict={x:x_real_data_for_nn_input, dropout_rate:1.})
# Out:
# epoch : 1
# cost : 191.012939453125
# epoch : 2
# cost : 193.5492706298828
# epoch : 3
# cost : 194.097412109375
# epoch : 4
# cost : 194.04017639160156
# epoch : 5
# cost : 194.28871154785156
# epoch : 6
# cost : 194.38784790039062
# epoch : 7
# cost : 194.10684204101562
# epoch : 8
# cost : 194.33961486816406
# epoch : 9
# cost : 194.1209259033203
# epoch : 10
# cost : 193.6640167236328
# epoch : 11
# cost : 192.98492431640625
# epoch : 12
# cost : 192.80914306640625
# epoch : 13
# cost : 192.50445556640625
# epoch : 14
# cost : 192.27734375
# epoch : 15
# cost : 191.9498291015625
# epoch : 16
# cost : 191.57943725585938
# epoch : 17
# cost : 191.2459716796875
# epoch : 18
# cost : 190.25892639160156
# epoch : 19
# cost : 189.55877685546875
# epoch : 20
# cost : 188.89682006835938
# epoch : 21
# cost : 182.17977905273438
# epoch : 22
# cost : 179.80967712402344
# epoch : 23
# cost : 177.61959838867188
# epoch : 24
# cost : 176.56204223632812
# epoch : 25
# cost : 175.39244079589844
# epoch : 26
# cost : 174.8076934814453
# epoch : 27
# cost : 174.63096618652344
# epoch : 28
# cost : 173.994873046875
# epoch : 29
# cost : 173.42141723632812
# epoch : 30
# cost : 173.1950225830078
# epoch : 31
# cost : 172.51913452148438
# epoch : 32
# cost : 172.0655059814453
# epoch : 33
# cost : 171.47061157226562
# epoch : 34
# cost : 170.8305206298828
# epoch : 35
# cost : 170.26449584960938
# epoch : 36
# cost : 170.05079650878906
# epoch : 37
# cost : 169.5284423828125
# epoch : 38
# cost : 169.99163818359375
# epoch : 39
# cost : 169.60235595703125
# epoch : 40
# cost : 169.3279266357422
# epoch : 41
# cost : 169.0063018798828
# epoch : 42
# cost : 167.9996337890625
# epoch : 43
# cost : 167.97845458984375
# cost : 8.391556739807129
# epoch : 483
# cost : 8.369545936584473
# epoch : 484
# cost : 8.348340034484863
# epoch : 485
# cost : 8.322710037231445
# epoch : 486
# cost : 8.295137405395508
# epoch : 487
# cost : 8.273625373840332
# epoch : 488
# cost : 8.252826690673828
# epoch : 489
# cost : 8.228547096252441
# epoch : 490
# cost : 8.202102661132812
# epoch : 491
# cost : 8.166791915893555
# epoch : 492
# cost : 8.131938934326172
# epoch : 493
# cost : 8.110994338989258
# epoch : 494
# cost : 8.081470489501953
# epoch : 495
# cost : 8.050188064575195
# epoch : 496
# cost : 8.022795677185059
# epoch : 497
# cost : 7.997591972351074
# epoch : 498
# cost : 7.962867259979248
# epoch : 499
# cost : 7.930689334869385
# epoch : 500
# cost : 7.8924994468688965

# %%
pred = np.exp(pred) - 1

# %%
pred
# Out:
# array([[29394.73],
#        [29394.73],
#        [29394.73],
#        ...,
#        [29394.73],
#        [29394.73],
#        [29394.73]], dtype=float32)

# %%
pd.DataFrame(pred).head()
# Out:
#               0
# 0  29394.730469
# 1  29394.730469
# 2  29394.730469
# 3  29394.730469
# 4  29394.730469

# %%
print(pred.min(), pred.max(), pred.mean())
# Out:
# 29394.73 29394.73 29394.73

# %%
pred = np.exp(pred) - 1

# %%
pd.DataFrame(train_label).head()

# %%
pd.Series(pred.flatten()).value_counts()

# %%
import xgboost as xgb

# %%
xgb_params = {
    'eta': 0.01,
    'max_depth': 6,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

print('Transform DMatrix...')
dtrain = xgb.DMatrix(xtrain, ytrain)
dtest = xgb.DMatrix(xtest)

print('Start Cross Validation...')

cv_output = xgb.cv(xgb_params, dtrain, num_boost_round=5000, early_stopping_rounds=20,verbose_eval=50, show_stdv=False)
cv_output[['train-rmse-mean', 'test-rmse-mean']].plot()
print('best num_boost_rounds = ', len(cv_output))
rounds = len(cv_output)
# Out:
# Transform DMatrix...
# Start Cross Validation...
# [0]	train-rmse:12.4335	test-rmse:12.4335
# [50]	train-rmse:7.52959	test-rmse:7.52957
# [100]	train-rmse:4.56344	test-rmse:4.56347
# [150]	train-rmse:2.77019	test-rmse:2.77037
# [200]	train-rmse:1.68708	test-rmse:1.6879
# [250]	train-rmse:1.03456	test-rmse:1.03665
# [300]	train-rmse:0.643961	test-rmse:0.648184
# [350]	train-rmse:0.413891	test-rmse:0.421342
# [400]	train-rmse:0.283031	test-rmse:0.294937
# [450]	train-rmse:0.212836	test-rmse:0.229655
# [500]	train-rmse:0.177407	test-rmse:0.198629
# [550]	train-rmse:0.159637	test-rmse:0.184322
# [600]	train-rmse:0.150214	test-rmse:0.177692
# [650]	train-rmse:0.144283	test-rmse:0.174232
# [700]	train-rmse:0.139961	test-rmse:0.172031
# [750]	train-rmse:0.136385	test-rmse:0.17063
# [800]	train-rmse:0.133259	test-rmse:0.16953
# [850]	train-rmse:0.13034	test-rmse:0.168569
# [900]	train-rmse:0.127699	test-rmse:0.167847
# [950]	train-rmse:0.125232	test-rmse:0.167286
# [1000]	train-rmse:0.122908	test-rmse:0.166739
# [1050]	train-rmse:0.120719	test-rmse:0.16633
# [1100]	train-rmse:0.118624	test-rmse:0.165906
# [1150]	train-rmse:0.11665	test-rmse:0.165572
# [1200]	train-rmse:0.114647	test-rmse:0.165291
# [1250]	train-rmse:0.11284	test-rmse:0.165039
# [1300]	train-rmse:0.111027	test-rmse:0.164747
# [1350]	train-rmse:0.109375	test-rmse:0.164575
# [1400]	train-rmse:0.107715	test-rmse:0.164392
# [1450]	train-rmse:0.106057	test-rmse:0.164204
# [1500]	train-rmse:0.104527	test-rmse:0.164072
# [1550]	train-rmse:0.102937	test-rmse:0.163881
# [1600]	train-rmse:0.101438	test-rmse:0.163711
# [1650]	train-rmse:0.100026	test-rmse:0.163631
# [1700]	train-rmse:0.0985443	test-rmse:0.163511
# [1750]	train-rmse:0.097173	test-rmse:0.163421
# [1800]	train-rmse:0.095822	test-rmse:0.163338
# [1850]	train-rmse:0.0945363	test-rmse:0.163248
# [1900]	train-rmse:0.093237	test-rmse:0.163164
# [1950]	train-rmse:0.09192	test-rmse:0.163068
# [2000]	train-rmse:0.0906947	test-rmse:0.162999
# best num_boost_rounds =  2001

# %%
xgb_params = {
    'eta': 0.01,
    'max_depth': 6,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

print('Transform DMatrix...')
dtrain = xgb.DMatrix(xdata, ydata)
dtest = xgb.DMatrix(x_real_data_scaled)

print('Start Cross Validation...')

cv_output = xgb.cv(xgb_params, dtrain, num_boost_round=5000, early_stopping_rounds=20,verbose_eval=50, show_stdv=False)
cv_output[['train-rmse-mean', 'test-rmse-mean']].plot()
print('best num_boost_rounds = ', len(cv_output))
rounds = len(cv_output)
# Out:
# Transform DMatrix...
# Start Cross Validation...
# [0]	train-rmse:12.4337	test-rmse:12.4337
# [50]	train-rmse:7.52914	test-rmse:7.5293
# [100]	train-rmse:4.56255	test-rmse:4.56278
# [150]	train-rmse:2.76905	test-rmse:2.76949
# [200]	train-rmse:1.68566	test-rmse:1.68654
# [250]	train-rmse:1.03295	test-rmse:1.03474
# [300]	train-rmse:0.642298	test-rmse:0.645688
# [350]	train-rmse:0.412514	test-rmse:0.418539
# [400]	train-rmse:0.282467	test-rmse:0.292161
# [450]	train-rmse:0.213354	test-rmse:0.227176
# [500]	train-rmse:0.1791	test-rmse:0.19654
# [550]	train-rmse:0.162228	test-rmse:0.18251
# [600]	train-rmse:0.153583	test-rmse:0.176261
# [650]	train-rmse:0.148384	test-rmse:0.173016
# [700]	train-rmse:0.144743	test-rmse:0.171111
# [750]	train-rmse:0.14177	test-rmse:0.169843
# [800]	train-rmse:0.139295	test-rmse:0.169058
# [850]	train-rmse:0.136879	test-rmse:0.168313
# [900]	train-rmse:0.134633	test-rmse:0.16768
# [950]	train-rmse:0.132582	test-rmse:0.167152
# [1000]	train-rmse:0.130661	test-rmse:0.166699
# [1050]	train-rmse:0.12887	test-rmse:0.166308
# [1100]	train-rmse:0.1271	test-rmse:0.165992
# [1150]	train-rmse:0.125492	test-rmse:0.165705
# [1200]	train-rmse:0.123832	test-rmse:0.165433
# [1250]	train-rmse:0.122291	test-rmse:0.165198
# [1300]	train-rmse:0.120814	test-rmse:0.164987
# [1350]	train-rmse:0.11934	test-rmse:0.164798
# [1400]	train-rmse:0.117896	test-rmse:0.16459
# [1450]	train-rmse:0.116531	test-rmse:0.164407
# [1500]	train-rmse:0.115145	test-rmse:0.164253
# [1550]	train-rmse:0.113821	test-rmse:0.164151
# [1600]	train-rmse:0.112624	test-rmse:0.164032
# [1650]	train-rmse:0.111398	test-rmse:0.1639
# [1700]	train-rmse:0.110187	test-rmse:0.163795
# [1750]	train-rmse:0.109018	test-rmse:0.163711
# [1800]	train-rmse:0.107855	test-rmse:0.163609
# [1850]	train-rmse:0.106782	test-rmse:0.163563
# [1900]	train-rmse:0.105609	test-rmse:0.163462
# [1950]	train-rmse:0.10449	test-rmse:0.163398
# [2000]	train-rmse:0.103428	test-rmse:0.163327
# [2050]	train-rmse:0.102396	test-rmse:0.163238
# [2100]	train-rmse:0.101393	test-rmse:0.163186
# best num_boost_rounds =  2101

# %%
xgb_params = {
    'eta': 0.01,
    'max_depth': 6,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}

print('Transform DMatrix...')
dtrain = xgb.DMatrix(xdata_raw, ydata)
dtest = xgb.DMatrix(x_real_data)

print('Start Cross Validation...')

cv_output = xgb.cv(xgb_params, dtrain, num_boost_round=5000, early_stopping_rounds=20,verbose_eval=50, show_stdv=False)
cv_output[['train-rmse-mean', 'test-rmse-mean']].plot()
print('best num_boost_rounds = ', len(cv_output))
rounds = len(cv_output)
# Out:
# Transform DMatrix...
# Start Cross Validation...
# [0]	train-rmse:12.4337	test-rmse:12.4337
# [50]	train-rmse:7.52914	test-rmse:7.5293
# [100]	train-rmse:4.56255	test-rmse:4.56277
# [150]	train-rmse:2.76904	test-rmse:2.76952
# [200]	train-rmse:1.68566	test-rmse:1.68657
# [250]	train-rmse:1.03296	test-rmse:1.03476
# [300]	train-rmse:0.642308	test-rmse:0.645711
# [350]	train-rmse:0.412524	test-rmse:0.418539
# [400]	train-rmse:0.282513	test-rmse:0.292202
# [450]	train-rmse:0.213435	test-rmse:0.22729
# [500]	train-rmse:0.179115	test-rmse:0.196585
# [550]	train-rmse:0.162206	test-rmse:0.182513
# [600]	train-rmse:0.153502	test-rmse:0.176211
# [650]	train-rmse:0.148428	test-rmse:0.173085
# [700]	train-rmse:0.144795	test-rmse:0.171205
# [750]	train-rmse:0.14177	test-rmse:0.169931
# [800]	train-rmse:0.139283	test-rmse:0.169134
# [850]	train-rmse:0.136818	test-rmse:0.168353
# [900]	train-rmse:0.134571	test-rmse:0.167744
# [950]	train-rmse:0.132523	test-rmse:0.167217
# [1000]	train-rmse:0.13057	test-rmse:0.16677
# [1050]	train-rmse:0.128781	test-rmse:0.166401
# [1100]	train-rmse:0.127035	test-rmse:0.166058
# [1150]	train-rmse:0.125431	test-rmse:0.16578
# [1200]	train-rmse:0.123814	test-rmse:0.165503
# [1250]	train-rmse:0.122226	test-rmse:0.165276
# [1300]	train-rmse:0.120768	test-rmse:0.165046
# [1350]	train-rmse:0.119315	test-rmse:0.164866
# [1400]	train-rmse:0.117882	test-rmse:0.164666
# [1450]	train-rmse:0.116494	test-rmse:0.164492
# [1500]	train-rmse:0.115094	test-rmse:0.164336
# [1550]	train-rmse:0.113797	test-rmse:0.164235
# [1600]	train-rmse:0.112605	test-rmse:0.164135
# [1650]	train-rmse:0.111414	test-rmse:0.164022
# [1700]	train-rmse:0.110213	test-rmse:0.163909
# [1750]	train-rmse:0.109021	test-rmse:0.163812
# [1800]	train-rmse:0.107877	test-rmse:0.163703
# [1850]	train-rmse:0.106778	test-rmse:0.16364
# [1900]	train-rmse:0.105632	test-rmse:0.163542
# [1950]	train-rmse:0.104527	test-rmse:0.163484
# [2000]	train-rmse:0.103469	test-rmse:0.163431
# [2050]	train-rmse:0.102413	test-rmse:0.163344
# [2100]	train-rmse:0.101407	test-rmse:0.163284
# [2150]	train-rmse:0.100406	test-rmse:0.163253
# [2200]	train-rmse:0.0994063	test-rmse:0.1632
# [2250]	train-rmse:0.0984277	test-rmse:0.163159
# [2300]	train-rmse:0.0975063	test-rmse:0.163126
# best num_boost_rounds =  2296

# %%
model = xgb.train(xgb_params, dtrain, num_boost_round = rounds)
preds = model.predict(dtest)

preds = np.exp(preds) - 1

sub = pd.DataFrame(test['id'])
sub['price'] = preds
sub.to_csv('sub_xgb_starter_1.csv', index=False)

# %%
import pandas as pd
sub = pd.DataFrame(test['id'])

# %%
test['id'].size
# Out:
# 6468

# %%
xtest.shape
# Out:
# (3758, 29)

# %%
pwd
# Out:
# '/content'

# %%
xdata_raw.shape
# Out:
# (15029, 26)

# %%
pd.DataFrame(xdata_raw)
# Out:
#              0         1         2   ...   23         24        25
# 0      1.386294  0.693147  7.074117  ...  0.0   9.368147  1.214207
# 1      1.098612  0.693147  6.647688  ...  0.0   9.257745  1.023549
# 2      1.386294  1.098612  7.427144  ...  0.0  11.307711  0.826257
# 3      1.386294  1.178655  7.447751  ...  0.0  10.626177  1.012780
# 4      1.386294  0.916291  6.966967  ...  0.0  10.032009  1.002206
# 5      1.386294  1.252763  8.177797  ...  0.0  22.185816  2.235851
# 6      1.098612  0.693147  7.057037  ...  0.0  16.093229  2.073329
# 7      1.386294  0.693147  7.266129  ...  0.0  10.119001  1.118771
# 8      1.386294  1.011601  7.223296  ...  0.0  10.997355  0.803580
# 9      1.791759  1.098612  7.501634  ...  0.0  10.884515  1.290916
# 10     1.609438  1.386294  7.989899  ...  0.0  19.961459  2.553149
# 11     1.386294  1.098612  7.544861  ...  0.0  11.669776  0.718175
# 12     1.609438  0.693147  7.378384  ...  0.0  11.105957  1.210106
# 13     1.098612  0.693147  7.090910  ...  0.0  11.057399  0.614020
# 14     1.386294  0.693147  7.131699  ...  0.0  10.175245  0.969801
# 15     1.609438  1.011601  7.390799  ...  0.0  19.676000  2.136672
# 16     1.386294  1.321756  8.023225  ...  0.0  18.810656  2.325909
# 17     1.098612  0.916291  6.976348  ...  0.0  10.364920  0.734363
# 18     1.386294  1.178655  7.804251  ...  0.0  11.594955  0.821512
